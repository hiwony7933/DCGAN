# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D, ReLU
from tensorflow.keras.models import Sequential, Model

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
import os
if not os.path.exists("./gan_images"):
    os.makedirs("./gan_images")
    
np.random.seed(3)
tf.random.set_seed(3)

# %%
depth = 64 + 64 + 64 + 64
g_model = Sequential()
g_model.add(Dense(depth*7*7, input_dim=100, activation='relu'))
g_model.add(BatchNormalization(momentum=0.9))
g_model.add(Reshape((7,7,128)))
g_model.add(Dropout(0.4))
g_model.add(UpSampling2D())

g_model.add(Conv2D(int(depth/2), kernel_size=5, padding='same', activation='relu'))
g_model.add(BatchNormalization(momentum=0.9))
g_model.add(UpSampling2D())

g_model.add(Conv2D(int(depth/4), kernel_size=5, padding='same',activation='relu'))
g_model.add(BatchNormalization(momentum=0.9))

g_model.add(Conv2D(int(depth/8), kernel_size=5, padding='same',activation='relu'))
g_model.add(BatchNormalization(momentum=0.9))

g_model.add(Conv2D(1, kernel_size=5, padding='same', activation='sigmoid'))
g_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 12544)             1266944
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 12544)             50176
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 7, 7, 128)         0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 14, 14, 128)       409728
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 64)        204864
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 28, 28, 64)        256
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 32)        51232
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 28, 28, 1)         801
# =================================================================
# Total params: 1,984,641
# Trainable params: 1,959,105
# Non-trainable params: 25,536
# _________________________________________________________________

# %%
d_model = Sequential()
d_model.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28, 28, 1), padding='same'))
d_model.add(Activation(LeakyReLU(0.2)))
d_model.add(Dropout(0.3))
d_model.add(Conv2D(128, kernel_size=5, strides=2, padding='same'))
d_model.add(Activation(LeakyReLU(0.2)))
d_model.add(Dropout(0.3))
d_model.add(Conv2D(256, kernel_size=5, strides=2, padding='same'))
d_model.add(Activation(LeakyReLU(0.2)))
d_model.add(Dropout(0.3))
d_model.add(Flatten())
d_model.add(Dense(1, activation='sigmoid'))
d_model.compile(loss='binary_crossentropy', optimizer='adam')
d_model.trainable = False
d_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 14, 14, 64)        1664
# _________________________________________________________________
# activation (Activation)      (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 128)         204928
# _________________________________________________________________
# activation_1 (Activation)    (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 256)         819456
# _________________________________________________________________
# activation_2 (Activation)    (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 4097
# =================================================================
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# Total params: 2,060,290
# Trainable params: 1,030,145
# Non-trainable params: 1,030,145
# _________________________________________________________________

# %%
g_input = Input(shape=(100,))
dis_output = d_model(g_model(g_input))
gan = Model(g_input, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 28, 28, 1)         928321
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 1030145
# =================================================================
# Total params: 1,958,466
# Trainable params: 915,553
# Non-trainable params: 1,042,913
# _________________________________________________________________

# %%
epoch= 1001
batch_size = 32
saving_interval = 100
history= []

(X_train, _), (_,_) = mnist.load_data()
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
X_train = X_train / 255.0
true = np.ones((batch_size, 1))
fake = np.zeros((batch_size, 1))

# %%
for i in range(epoch) :
    idx = np.random.randint(0, X_train.shape[0], batch_size)
    imgs = X_train[idx]
    d_loss_real = d_model.train_on_batch(imgs, true)
    
    noise = np.random.normal(0, 1, (batch_size, 100))
    gen_imgs = g_model.predict(noise)
    d_loss_fake = d_model.train_on_batch(gen_imgs, fake) 

    
    d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
    g_loss = gan.train_on_batch(noise, true) 

    # 기록
    record = (epoch, d_loss, g_loss)
    history.append(record)
    
    print('epoch:%d' %i, ' d_Loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss) 


    
    if i % saving_interval == 0:
        #r, c = 5, 5
        noise = np.random.normal(0, 1, (25, 100))
        gen_imgs = g_model.predict(noise)

        # Rescale images 0 - 1
        gen_imgs = 0.5 * gen_imgs + 0.5

        fig, axs = plt.subplots(5, 5)
        count = 0
        for j in range(5):
          for k in range(5):
              axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
              axs[j, k].axis('off')
              count += 1
        fig.savefig("gan_images/gan_mnist_%d.png" % i)
# Out:
# epoch:0  d_Loss:0.8426  g_loss:0.7129
# epoch:1  d_Loss:0.6111  g_loss:0.8525
# epoch:2  d_Loss:0.5472  g_loss:0.9991
# epoch:3  d_Loss:0.4047  g_loss:1.1378
# epoch:4  d_Loss:0.2074  g_loss:1.1599
# epoch:5  d_Loss:0.0640  g_loss:0.6784
# epoch:6  d_Loss:0.0096  g_loss:0.4350
# epoch:7  d_Loss:0.0014  g_loss:0.3517
# epoch:8  d_Loss:0.0002  g_loss:0.1868
# epoch:9  d_Loss:0.0000  g_loss:0.0224
# epoch:10  d_Loss:0.0000  g_loss:0.4148
# epoch:11  d_Loss:0.0000  g_loss:0.4174
# epoch:12  d_Loss:0.0000  g_loss:0.1249
# epoch:13  d_Loss:0.0000  g_loss:0.3556
# epoch:14  d_Loss:0.0000  g_loss:0.8975
# epoch:15  d_Loss:0.0000  g_loss:0.2289
# epoch:16  d_Loss:0.0000  g_loss:0.4733
# epoch:17  d_Loss:0.0000  g_loss:0.7580
# epoch:18  d_Loss:0.0000  g_loss:0.1536
# epoch:19  d_Loss:0.0000  g_loss:0.0010
# epoch:20  d_Loss:0.0000  g_loss:0.0145
# epoch:21  d_Loss:0.0000  g_loss:0.8365
# epoch:22  d_Loss:0.0000  g_loss:0.7137
# epoch:23  d_Loss:0.0000  g_loss:1.5082
# epoch:24  d_Loss:0.0000  g_loss:0.7846
# epoch:25  d_Loss:0.0000  g_loss:0.0011
# epoch:26  d_Loss:0.0000  g_loss:0.8360
# epoch:27  d_Loss:0.0000  g_loss:0.0663
# epoch:28  d_Loss:0.0000  g_loss:0.0000
# epoch:29  d_Loss:0.0000  g_loss:0.2159
# epoch:30  d_Loss:0.0000  g_loss:0.0663
# epoch:31  d_Loss:0.0000  g_loss:0.0008
# epoch:32  d_Loss:0.0000  g_loss:0.5406
# epoch:33  d_Loss:0.0000  g_loss:0.1286
# epoch:34  d_Loss:0.0000  g_loss:0.2250
# epoch:35  d_Loss:0.0000  g_loss:0.2031
# epoch:36  d_Loss:0.0000  g_loss:0.0245
# epoch:37  d_Loss:0.0000  g_loss:0.0055
# epoch:38  d_Loss:0.0000  g_loss:0.1501
# epoch:39  d_Loss:0.0001  g_loss:0.0002
# epoch:40  d_Loss:0.0003  g_loss:0.0036
# epoch:41  d_Loss:0.0001  g_loss:0.0877
# epoch:42  d_Loss:0.0001  g_loss:0.0009
# epoch:43  d_Loss:0.0001  g_loss:0.0490
# epoch:44  d_Loss:0.0002  g_loss:0.7040
# epoch:45  d_Loss:0.0001  g_loss:0.4847
# epoch:46  d_Loss:0.0002  g_loss:0.0560
# epoch:47  d_Loss:0.0003  g_loss:0.1884
# epoch:48  d_Loss:0.0003  g_loss:0.4417
# epoch:49  d_Loss:0.0004  g_loss:0.0682
# epoch:50  d_Loss:0.0006  g_loss:0.1109
# epoch:51  d_Loss:0.0006  g_loss:0.2211
# epoch:52  d_Loss:0.0005  g_loss:0.6404
# epoch:53  d_Loss:0.0005  g_loss:0.4076
# epoch:54  d_Loss:0.0005  g_loss:1.6805
# epoch:55  d_Loss:0.0033  g_loss:0.1509
# epoch:56  d_Loss:0.0039  g_loss:0.7031
# epoch:57  d_Loss:0.0856  g_loss:1.8770
# epoch:58  d_Loss:0.0003  g_loss:5.2650
# epoch:59  d_Loss:0.5883  g_loss:0.0000
# epoch:60  d_Loss:0.3619  g_loss:0.0000
# epoch:61  d_Loss:0.0789  g_loss:0.0000
# epoch:62  d_Loss:0.0341  g_loss:0.0000
# epoch:63  d_Loss:0.0150  g_loss:0.0000
# epoch:64  d_Loss:0.0244  g_loss:0.1778
# epoch:65  d_Loss:0.2311  g_loss:0.0013
# epoch:66  d_Loss:0.0233  g_loss:0.0014
# epoch:67  d_Loss:0.0197  g_loss:0.0000
# epoch:68  d_Loss:0.0058  g_loss:0.3265
# epoch:69  d_Loss:0.0045  g_loss:0.0084
# epoch:70  d_Loss:0.0218  g_loss:0.3752
# epoch:71  d_Loss:0.0187  g_loss:0.0845
# epoch:72  d_Loss:0.0066  g_loss:0.0000
# epoch:73  d_Loss:0.0051  g_loss:0.1681
# epoch:74  d_Loss:0.0102  g_loss:0.0003
# epoch:75  d_Loss:0.0046  g_loss:0.2964
# epoch:76  d_Loss:0.0046  g_loss:0.0000
# epoch:77  d_Loss:0.0710  g_loss:0.0000
# epoch:78  d_Loss:0.0038  g_loss:0.2836
# epoch:79  d_Loss:0.0032  g_loss:0.8995
# epoch:80  d_Loss:0.0026  g_loss:0.0547
# epoch:81  d_Loss:0.0022  g_loss:0.2754
# epoch:82  d_Loss:0.0020  g_loss:0.2983
# epoch:83  d_Loss:0.0021  g_loss:0.0541
# epoch:84  d_Loss:0.0016  g_loss:0.4821
# epoch:85  d_Loss:0.0015  g_loss:0.5815
# epoch:86  d_Loss:0.0052  g_loss:1.6552
# epoch:87  d_Loss:0.0141  g_loss:1.2028
# epoch:88  d_Loss:0.0016  g_loss:0.3557
# epoch:89  d_Loss:0.0013  g_loss:0.4431
# epoch:90  d_Loss:0.0120  g_loss:0.5063
# epoch:91  d_Loss:0.0011  g_loss:0.0513
# epoch:92  d_Loss:0.0009  g_loss:0.0055
# epoch:93  d_Loss:0.0008  g_loss:0.0020
# epoch:94  d_Loss:0.1747  g_loss:0.0191
# epoch:95  d_Loss:0.0268  g_loss:0.0000
# epoch:96  d_Loss:0.0005  g_loss:0.0000
# epoch:97  d_Loss:0.0002  g_loss:0.0002
# epoch:98  d_Loss:0.0007  g_loss:0.5640
# epoch:99  d_Loss:0.0023  g_loss:0.0029
# epoch:100  d_Loss:0.2398  g_loss:0.1274
# epoch:101  d_Loss:0.0140  g_loss:0.4861
# epoch:102  d_Loss:0.0033  g_loss:0.0000
# epoch:103  d_Loss:0.0179  g_loss:0.1016
# epoch:104  d_Loss:0.0021  g_loss:0.4827
# epoch:105  d_Loss:0.0002  g_loss:0.0980
# epoch:106  d_Loss:0.1121  g_loss:0.4820
# epoch:107  d_Loss:0.0424  g_loss:0.4943
# epoch:108  d_Loss:0.2189  g_loss:1.0190
# epoch:109  d_Loss:0.3830  g_loss:0.1559
# epoch:110  d_Loss:0.0167  g_loss:0.0000
# epoch:111  d_Loss:0.0591  g_loss:0.2905
# epoch:112  d_Loss:0.0542  g_loss:0.0001
# epoch:113  d_Loss:0.0062  g_loss:0.0000
# epoch:114  d_Loss:0.0404  g_loss:0.0000
# epoch:115  d_Loss:0.0020  g_loss:0.0000
# epoch:116  d_Loss:0.0411  g_loss:0.0061
# epoch:117  d_Loss:0.2807  g_loss:0.3611
# epoch:118  d_Loss:0.3407  g_loss:0.0022
# epoch:119  d_Loss:0.2872  g_loss:0.1826
# epoch:120  d_Loss:0.2556  g_loss:0.0240
# epoch:121  d_Loss:0.4893  g_loss:0.2222
# epoch:122  d_Loss:0.3289  g_loss:0.0027
# epoch:123  d_Loss:0.0946  g_loss:0.0396
# epoch:124  d_Loss:0.0374  g_loss:0.1357
# epoch:125  d_Loss:0.4221  g_loss:0.0014
# epoch:126  d_Loss:0.1596  g_loss:0.0004
# epoch:127  d_Loss:0.1055  g_loss:0.0002
# epoch:128  d_Loss:0.0976  g_loss:0.0003
# epoch:129  d_Loss:0.2928  g_loss:0.0024
# epoch:130  d_Loss:0.1400  g_loss:0.0033
# epoch:131  d_Loss:0.0203  g_loss:0.1584
# epoch:132  d_Loss:0.0240  g_loss:0.4450
# epoch:133  d_Loss:0.0571  g_loss:0.3325
# epoch:134  d_Loss:0.1058  g_loss:0.1884
# epoch:135  d_Loss:0.1077  g_loss:0.0330
# epoch:136  d_Loss:0.0624  g_loss:0.0005
# epoch:137  d_Loss:0.0179  g_loss:0.0008
# epoch:138  d_Loss:0.1152  g_loss:0.0000
# epoch:139  d_Loss:0.0524  g_loss:0.0007
# epoch:140  d_Loss:0.0655  g_loss:0.0027
# epoch:141  d_Loss:0.0298  g_loss:0.0001
# epoch:142  d_Loss:0.0821  g_loss:0.0013
# epoch:143  d_Loss:0.0275  g_loss:0.0044
# epoch:144  d_Loss:0.0291  g_loss:0.0072
# epoch:145  d_Loss:0.0542  g_loss:0.0163
# epoch:146  d_Loss:0.0259  g_loss:0.0048
# epoch:147  d_Loss:0.0446  g_loss:0.0071
# epoch:148  d_Loss:0.0377  g_loss:0.0001
# epoch:149  d_Loss:0.0122  g_loss:0.0231
# epoch:150  d_Loss:0.0092  g_loss:0.1003
# epoch:151  d_Loss:0.0067  g_loss:0.0016
# epoch:152  d_Loss:0.0064  g_loss:0.0110
# epoch:153  d_Loss:0.0145  g_loss:0.0008
# epoch:154  d_Loss:0.0115  g_loss:0.0014
# epoch:155  d_Loss:0.0212  g_loss:0.0001
# epoch:156  d_Loss:0.1231  g_loss:0.0120
# epoch:157  d_Loss:0.0446  g_loss:0.0034
# epoch:158  d_Loss:0.0515  g_loss:0.0048
# epoch:159  d_Loss:0.0051  g_loss:0.0123
# epoch:160  d_Loss:0.0059  g_loss:0.0047
# epoch:161  d_Loss:0.0058  g_loss:0.0002
# epoch:162  d_Loss:0.0596  g_loss:0.0002
# epoch:163  d_Loss:0.0069  g_loss:0.0047
# epoch:164  d_Loss:0.0156  g_loss:0.0462
# epoch:165  d_Loss:0.0029  g_loss:0.0000
# epoch:166  d_Loss:0.0013  g_loss:0.0004
# epoch:167  d_Loss:0.0096  g_loss:0.0000
# epoch:168  d_Loss:0.0379  g_loss:0.0000
# epoch:169  d_Loss:0.0368  g_loss:0.0001
# epoch:170  d_Loss:0.0009  g_loss:0.0000
# epoch:171  d_Loss:0.0022  g_loss:0.0005
# epoch:172  d_Loss:0.0050  g_loss:0.0065
# epoch:173  d_Loss:0.0058  g_loss:0.0001
# epoch:174  d_Loss:0.0098  g_loss:0.0001
# epoch:175  d_Loss:0.0141  g_loss:0.0001
# epoch:176  d_Loss:0.0035  g_loss:0.0001
# epoch:177  d_Loss:0.0033  g_loss:0.0000
# epoch:178  d_Loss:0.0552  g_loss:0.0001
# epoch:179  d_Loss:0.0296  g_loss:0.0001
# epoch:180  d_Loss:0.0060  g_loss:0.0002
# epoch:181  d_Loss:0.0080  g_loss:0.0028
# epoch:182  d_Loss:0.0211  g_loss:0.0080
# epoch:183  d_Loss:0.0816  g_loss:0.0001
# epoch:184  d_Loss:0.0148  g_loss:0.0001
# epoch:185  d_Loss:0.0061  g_loss:0.0001
# epoch:186  d_Loss:0.0079  g_loss:0.0007
# epoch:187  d_Loss:0.1167  g_loss:0.0002
# epoch:188  d_Loss:0.1944  g_loss:0.0001
# epoch:189  d_Loss:0.0050  g_loss:0.0019
# epoch:190  d_Loss:0.0158  g_loss:0.0008
# epoch:191  d_Loss:0.0079  g_loss:0.0007
# epoch:192  d_Loss:0.0283  g_loss:0.0186
# epoch:193  d_Loss:0.0104  g_loss:0.0347
# epoch:194  d_Loss:0.0144  g_loss:0.0027
# epoch:195  d_Loss:0.0505  g_loss:0.0010
# epoch:196  d_Loss:0.0139  g_loss:0.0002
# epoch:197  d_Loss:0.0167  g_loss:0.0022
# epoch:198  d_Loss:0.0046  g_loss:0.0002
# epoch:199  d_Loss:0.0104  g_loss:0.0001
# epoch:200  d_Loss:0.0058  g_loss:0.0042
# epoch:201  d_Loss:0.0141  g_loss:0.0006
# epoch:202  d_Loss:0.0819  g_loss:0.0003
# epoch:203  d_Loss:0.0162  g_loss:0.0011
# epoch:204  d_Loss:0.0199  g_loss:0.0011
# epoch:205  d_Loss:0.0230  g_loss:0.0047
# epoch:206  d_Loss:0.0477  g_loss:0.0023
# epoch:207  d_Loss:0.0145  g_loss:0.0111
# epoch:208  d_Loss:0.0251  g_loss:0.0079
# epoch:209  d_Loss:0.0156  g_loss:0.0146
# epoch:210  d_Loss:0.0098  g_loss:0.0001
# epoch:211  d_Loss:0.0065  g_loss:0.0000
# epoch:212  d_Loss:0.0451  g_loss:0.0001
# epoch:213  d_Loss:0.0673  g_loss:0.0000
# epoch:214  d_Loss:0.0067  g_loss:0.0001
# epoch:215  d_Loss:0.0020  g_loss:0.0002
# epoch:216  d_Loss:0.0181  g_loss:0.0029
# epoch:217  d_Loss:0.0056  g_loss:0.1363
# epoch:218  d_Loss:0.0107  g_loss:0.0073
# epoch:219  d_Loss:0.0489  g_loss:0.0025
# epoch:220  d_Loss:0.0285  g_loss:0.0001
# epoch:221  d_Loss:0.0023  g_loss:0.0005
# epoch:222  d_Loss:0.0160  g_loss:0.0021
# epoch:223  d_Loss:0.0116  g_loss:0.0002
# epoch:224  d_Loss:0.0391  g_loss:0.0018
# epoch:225  d_Loss:0.0449  g_loss:0.0024
# epoch:226  d_Loss:0.0050  g_loss:0.0034
# epoch:227  d_Loss:0.0167  g_loss:0.0258
# epoch:228  d_Loss:0.0141  g_loss:0.0010
# epoch:229  d_Loss:0.0611  g_loss:0.0002
# epoch:230  d_Loss:0.0204  g_loss:0.0018
# epoch:231  d_Loss:0.1970  g_loss:0.0000
# epoch:232  d_Loss:0.0072  g_loss:0.0002
# epoch:233  d_Loss:0.0160  g_loss:0.0032
# epoch:234  d_Loss:0.0529  g_loss:0.0075
# epoch:235  d_Loss:0.0100  g_loss:0.0023
# epoch:236  d_Loss:0.0896  g_loss:0.0001
# epoch:237  d_Loss:0.0401  g_loss:0.0002
# epoch:238  d_Loss:0.0780  g_loss:0.0000
# epoch:239  d_Loss:0.0903  g_loss:0.0007
# epoch:240  d_Loss:0.0025  g_loss:0.0342
# epoch:241  d_Loss:0.0375  g_loss:0.0096
# epoch:242  d_Loss:0.0535  g_loss:0.0122
# epoch:243  d_Loss:0.1154  g_loss:0.0003
# epoch:244  d_Loss:0.0252  g_loss:0.0008
# epoch:245  d_Loss:0.0193  g_loss:0.0003
# epoch:246  d_Loss:0.0243  g_loss:0.0016
# epoch:247  d_Loss:0.1140  g_loss:0.0083
# epoch:248  d_Loss:0.0074  g_loss:0.0380
# epoch:249  d_Loss:0.0550  g_loss:0.0071
# epoch:250  d_Loss:0.0277  g_loss:0.0143
# epoch:251  d_Loss:0.0183  g_loss:0.0069
# epoch:252  d_Loss:0.0403  g_loss:0.0007
# epoch:253  d_Loss:0.0788  g_loss:0.0015
# epoch:254  d_Loss:0.0114  g_loss:0.0095
# epoch:255  d_Loss:0.0188  g_loss:0.0291
# epoch:256  d_Loss:0.0975  g_loss:0.0027
# epoch:257  d_Loss:0.0528  g_loss:0.0006
# epoch:258  d_Loss:0.0853  g_loss:0.0007
# epoch:259  d_Loss:0.0187  g_loss:0.0011
# epoch:260  d_Loss:0.0306  g_loss:0.0024
# epoch:261  d_Loss:0.0144  g_loss:0.0309
# epoch:262  d_Loss:0.0423  g_loss:0.0190
# epoch:263  d_Loss:0.0443  g_loss:0.0105
# epoch:264  d_Loss:0.0145  g_loss:0.0016
# epoch:265  d_Loss:0.0214  g_loss:0.0096
# epoch:266  d_Loss:0.0642  g_loss:0.0103
# epoch:267  d_Loss:0.0838  g_loss:0.0023
# epoch:268  d_Loss:0.0065  g_loss:0.0070
# epoch:269  d_Loss:0.0372  g_loss:0.0296
# epoch:270  d_Loss:0.0080  g_loss:0.0180
# epoch:271  d_Loss:0.0965  g_loss:0.0031
# epoch:272  d_Loss:0.0104  g_loss:0.0103
# epoch:273  d_Loss:0.0105  g_loss:0.0063
# epoch:274  d_Loss:0.0642  g_loss:0.0057
# epoch:275  d_Loss:0.0364  g_loss:0.0186
# epoch:276  d_Loss:0.0245  g_loss:0.0265
# epoch:277  d_Loss:0.0111  g_loss:0.0706
# epoch:278  d_Loss:0.0347  g_loss:0.0236
# epoch:279  d_Loss:0.0456  g_loss:0.0050
# epoch:280  d_Loss:0.0269  g_loss:0.0282
# epoch:281  d_Loss:0.0583  g_loss:0.0091
# epoch:282  d_Loss:0.0154  g_loss:0.0037
# epoch:283  d_Loss:0.0725  g_loss:0.0003
# epoch:284  d_Loss:0.1005  g_loss:0.0015
# epoch:285  d_Loss:0.0877  g_loss:0.0971
# epoch:286  d_Loss:0.1149  g_loss:0.0833
# epoch:287  d_Loss:0.0506  g_loss:0.0006
# epoch:288  d_Loss:0.1529  g_loss:0.0001
# epoch:289  d_Loss:0.4118  g_loss:0.0018
# epoch:290  d_Loss:0.0177  g_loss:0.2286
# epoch:291  d_Loss:0.3232  g_loss:0.0348
# epoch:292  d_Loss:0.1556  g_loss:0.0013
# epoch:293  d_Loss:0.2403  g_loss:0.0027
# epoch:294  d_Loss:0.1034  g_loss:0.0056
# epoch:295  d_Loss:0.1540  g_loss:0.0447
# epoch:296  d_Loss:0.0526  g_loss:0.0923
# epoch:297  d_Loss:0.3030  g_loss:0.0077
# epoch:298  d_Loss:0.2826  g_loss:0.0103
# epoch:299  d_Loss:0.0387  g_loss:0.0337
# epoch:300  d_Loss:0.0443  g_loss:0.0923
# epoch:301  d_Loss:0.1306  g_loss:0.0554
# epoch:302  d_Loss:0.1438  g_loss:0.0541
# epoch:303  d_Loss:0.1845  g_loss:0.0308
# epoch:304  d_Loss:0.1226  g_loss:0.0428
# epoch:305  d_Loss:0.0663  g_loss:0.0904
# epoch:306  d_Loss:0.1542  g_loss:0.0309
# epoch:307  d_Loss:0.1580  g_loss:0.3114
# epoch:308  d_Loss:0.0728  g_loss:0.3348
# epoch:309  d_Loss:0.1164  g_loss:0.2601
# epoch:310  d_Loss:0.1859  g_loss:0.1404
# epoch:311  d_Loss:0.1411  g_loss:0.9173
# epoch:312  d_Loss:0.0929  g_loss:1.0087
# epoch:313  d_Loss:0.3024  g_loss:0.0251
# epoch:314  d_Loss:0.2953  g_loss:0.0349
# epoch:315  d_Loss:0.0227  g_loss:0.4490
# epoch:316  d_Loss:0.3232  g_loss:0.0844
# epoch:317  d_Loss:0.2912  g_loss:0.0273
# epoch:318  d_Loss:0.3255  g_loss:0.0523
# epoch:319  d_Loss:0.3329  g_loss:0.1390
# epoch:320  d_Loss:0.2994  g_loss:0.2225
# epoch:321  d_Loss:0.2775  g_loss:0.1271
# epoch:322  d_Loss:0.1105  g_loss:0.2972
# epoch:323  d_Loss:0.1945  g_loss:1.2694
# epoch:324  d_Loss:0.3747  g_loss:0.5968
# epoch:325  d_Loss:0.4216  g_loss:0.5090
# epoch:326  d_Loss:0.3331  g_loss:1.0652
# epoch:327  d_Loss:0.4146  g_loss:1.7176
# epoch:328  d_Loss:0.4412  g_loss:0.7155
# epoch:329  d_Loss:0.2401  g_loss:0.5722
# epoch:330  d_Loss:0.3432  g_loss:1.1158
# epoch:331  d_Loss:0.1443  g_loss:2.8453
# epoch:332  d_Loss:0.6028  g_loss:1.0086
# epoch:333  d_Loss:0.3734  g_loss:0.5936
# epoch:334  d_Loss:0.3147  g_loss:1.2261
# epoch:335  d_Loss:0.1997  g_loss:3.2597
# epoch:336  d_Loss:0.2077  g_loss:4.2900
# epoch:337  d_Loss:0.3672  g_loss:3.3410
# epoch:338  d_Loss:0.4105  g_loss:2.0196
# epoch:339  d_Loss:0.3837  g_loss:2.9641
# epoch:340  d_Loss:0.2932  g_loss:3.8133
# epoch:341  d_Loss:0.2946  g_loss:4.4478
# epoch:342  d_Loss:0.1713  g_loss:3.6119
# epoch:343  d_Loss:0.3292  g_loss:2.0424
# epoch:344  d_Loss:0.4107  g_loss:1.2535
# epoch:345  d_Loss:0.4716  g_loss:2.3006
# epoch:346  d_Loss:0.3578  g_loss:2.8020
# epoch:347  d_Loss:0.3099  g_loss:2.9001
# epoch:348  d_Loss:0.2483  g_loss:2.9957
# epoch:349  d_Loss:0.2618  g_loss:2.2610
# epoch:350  d_Loss:0.2263  g_loss:2.3947
# epoch:351  d_Loss:0.2062  g_loss:2.6109
# epoch:352  d_Loss:0.2079  g_loss:3.9924
# epoch:353  d_Loss:0.3491  g_loss:3.2794
# epoch:354  d_Loss:0.2377  g_loss:3.1498
# epoch:355  d_Loss:0.3114  g_loss:2.9692
# epoch:356  d_Loss:0.2062  g_loss:4.7180
# epoch:357  d_Loss:0.4089  g_loss:2.9840
# epoch:358  d_Loss:0.4411  g_loss:2.6400
# epoch:359  d_Loss:0.2213  g_loss:3.7249
# epoch:360  d_Loss:0.0969  g_loss:4.6094
# epoch:361  d_Loss:0.5297  g_loss:4.5103
# epoch:362  d_Loss:0.3038  g_loss:3.7353
# epoch:363  d_Loss:0.2851  g_loss:3.3236
# epoch:364  d_Loss:0.2289  g_loss:2.9999
# epoch:365  d_Loss:0.2460  g_loss:3.6217
# epoch:366  d_Loss:0.2641  g_loss:4.5448
# epoch:367  d_Loss:0.2248  g_loss:4.1080
# epoch:368  d_Loss:0.3223  g_loss:3.6812
# epoch:369  d_Loss:0.2537  g_loss:4.7231
# epoch:370  d_Loss:0.2586  g_loss:5.3624
# epoch:371  d_Loss:0.1241  g_loss:7.0852
# epoch:372  d_Loss:0.2667  g_loss:6.0230
# epoch:373  d_Loss:0.3475  g_loss:3.7381
# epoch:374  d_Loss:0.3704  g_loss:3.6682
# epoch:375  d_Loss:0.1660  g_loss:6.6331
# epoch:376  d_Loss:0.2105  g_loss:7.0170
# epoch:377  d_Loss:0.4587  g_loss:5.3537
# epoch:378  d_Loss:0.1704  g_loss:4.0469
# epoch:379  d_Loss:0.2576  g_loss:2.9356
# epoch:380  d_Loss:0.3144  g_loss:4.1588
# epoch:381  d_Loss:0.0969  g_loss:6.2237
# epoch:382  d_Loss:0.2994  g_loss:6.4625
# epoch:383  d_Loss:0.4313  g_loss:4.2695
# epoch:384  d_Loss:0.3970  g_loss:3.4916
# epoch:385  d_Loss:0.4520  g_loss:3.6571
# epoch:386  d_Loss:0.2525  g_loss:4.8752
# epoch:387  d_Loss:0.1548  g_loss:5.3019
# epoch:388  d_Loss:0.3172  g_loss:3.7934
# epoch:389  d_Loss:0.2445  g_loss:3.2926
# epoch:390  d_Loss:0.2791  g_loss:2.8098
# epoch:391  d_Loss:0.2311  g_loss:3.4234
# epoch:392  d_Loss:0.3254  g_loss:4.1128
# epoch:393  d_Loss:0.3513  g_loss:2.9450
# epoch:394  d_Loss:0.2878  g_loss:3.8177
# epoch:395  d_Loss:0.3750  g_loss:3.3914
# epoch:396  d_Loss:0.1728  g_loss:4.0966
# epoch:397  d_Loss:0.2702  g_loss:4.0513
# epoch:398  d_Loss:0.3160  g_loss:3.5858
# epoch:399  d_Loss:0.4738  g_loss:2.7899
# epoch:400  d_Loss:0.2381  g_loss:3.9215
# epoch:401  d_Loss:0.1450  g_loss:4.0140
# epoch:402  d_Loss:0.2165  g_loss:4.0219
# epoch:403  d_Loss:0.2646  g_loss:3.4350
# epoch:404  d_Loss:0.2447  g_loss:2.5799
# epoch:405  d_Loss:0.3021  g_loss:2.2199
# epoch:406  d_Loss:0.3160  g_loss:3.5896
# epoch:407  d_Loss:0.1295  g_loss:5.4175
# epoch:408  d_Loss:0.2888  g_loss:5.5023
# epoch:409  d_Loss:0.5760  g_loss:2.7678
# epoch:410  d_Loss:0.4453  g_loss:1.7130
# epoch:411  d_Loss:0.3809  g_loss:2.4262
# epoch:412  d_Loss:0.2713  g_loss:3.3631
# epoch:413  d_Loss:0.3318  g_loss:3.8079
# epoch:414  d_Loss:0.2864  g_loss:3.1209
# epoch:415  d_Loss:0.1957  g_loss:2.2131
# epoch:416  d_Loss:0.1108  g_loss:1.6173
# epoch:417  d_Loss:0.1703  g_loss:2.5332
# epoch:418  d_Loss:0.0836  g_loss:3.2312
# epoch:419  d_Loss:0.1606  g_loss:3.2099
# epoch:420  d_Loss:0.1578  g_loss:2.5906
# epoch:421  d_Loss:0.2175  g_loss:2.0038
# epoch:422  d_Loss:0.1349  g_loss:1.6732
# epoch:423  d_Loss:0.1526  g_loss:1.4805
# epoch:424  d_Loss:0.2064  g_loss:2.2375
# epoch:425  d_Loss:0.2277  g_loss:2.7595
# epoch:426  d_Loss:0.2938  g_loss:1.4748
# epoch:427  d_Loss:0.2365  g_loss:1.3942
# epoch:428  d_Loss:0.5924  g_loss:1.2177
# epoch:429  d_Loss:0.1110  g_loss:2.4417
# epoch:430  d_Loss:0.2297  g_loss:2.6860
# epoch:431  d_Loss:0.2933  g_loss:2.2939
# epoch:432  d_Loss:0.3677  g_loss:1.4915
# epoch:433  d_Loss:0.4125  g_loss:1.7951
# epoch:434  d_Loss:0.2027  g_loss:2.4906
# epoch:435  d_Loss:0.1847  g_loss:3.2271
# epoch:436  d_Loss:0.4917  g_loss:1.9446
# epoch:437  d_Loss:0.3968  g_loss:1.6110
# epoch:438  d_Loss:0.4141  g_loss:2.4305
# epoch:439  d_Loss:0.2626  g_loss:3.7011
# epoch:440  d_Loss:0.4381  g_loss:3.2488
# epoch:441  d_Loss:0.4328  g_loss:2.3307
# epoch:442  d_Loss:0.3418  g_loss:2.6472
# epoch:443  d_Loss:0.4129  g_loss:3.5159
# epoch:444  d_Loss:0.4296  g_loss:3.1702
# epoch:445  d_Loss:0.2390  g_loss:2.5782
# epoch:446  d_Loss:0.2778  g_loss:2.8356
# epoch:447  d_Loss:0.3326  g_loss:2.6040
# epoch:448  d_Loss:0.2393  g_loss:2.7702
# epoch:449  d_Loss:0.2656  g_loss:3.1055
# epoch:450  d_Loss:0.3393  g_loss:3.3472
# epoch:451  d_Loss:0.2402  g_loss:2.9455
# epoch:452  d_Loss:0.3537  g_loss:3.0439
# epoch:453  d_Loss:0.2254  g_loss:2.9096
# epoch:454  d_Loss:0.1903  g_loss:3.6106
# epoch:455  d_Loss:0.2943  g_loss:3.6785
# epoch:456  d_Loss:0.3054  g_loss:3.7050
# epoch:457  d_Loss:0.1597  g_loss:3.4307
# epoch:458  d_Loss:0.3561  g_loss:2.5015
# epoch:459  d_Loss:0.2523  g_loss:4.2096
# epoch:460  d_Loss:0.3378  g_loss:3.4425
# epoch:461  d_Loss:0.4048  g_loss:3.3422
# epoch:462  d_Loss:0.2511  g_loss:3.3586
# epoch:463  d_Loss:0.1612  g_loss:3.1654
# epoch:464  d_Loss:0.2801  g_loss:2.4493
# epoch:465  d_Loss:0.2711  g_loss:3.3116
# epoch:466  d_Loss:0.1499  g_loss:3.3421
# epoch:467  d_Loss:0.2319  g_loss:3.3798
# epoch:468  d_Loss:0.1636  g_loss:2.7756
# epoch:469  d_Loss:0.2862  g_loss:3.2758
# epoch:470  d_Loss:0.1225  g_loss:3.3703
# epoch:471  d_Loss:0.1921  g_loss:2.7463
# epoch:472  d_Loss:0.3034  g_loss:1.9254
# epoch:473  d_Loss:0.2094  g_loss:3.4044
# epoch:474  d_Loss:0.3899  g_loss:3.3280
# epoch:475  d_Loss:0.4387  g_loss:2.2855
# epoch:476  d_Loss:0.2330  g_loss:2.8952
# epoch:477  d_Loss:0.3740  g_loss:2.9258
# epoch:478  d_Loss:0.1691  g_loss:3.2979
# epoch:479  d_Loss:0.3720  g_loss:1.9492
# epoch:480  d_Loss:0.3134  g_loss:1.9851
# epoch:481  d_Loss:0.1555  g_loss:4.0377
# epoch:482  d_Loss:0.0816  g_loss:5.6454
# epoch:483  d_Loss:0.5548  g_loss:2.4209
# epoch:484  d_Loss:0.2934  g_loss:2.5710
# epoch:485  d_Loss:0.3801  g_loss:4.6562
# epoch:486  d_Loss:0.1521  g_loss:5.4245
# epoch:487  d_Loss:0.4856  g_loss:2.6538
# epoch:488  d_Loss:0.5976  g_loss:2.1145
# epoch:489  d_Loss:0.4764  g_loss:3.5733
# epoch:490  d_Loss:0.2138  g_loss:4.3689
# epoch:491  d_Loss:0.3619  g_loss:3.6271
# epoch:492  d_Loss:0.2924  g_loss:2.5798
# epoch:493  d_Loss:0.4491  g_loss:2.1214
# epoch:494  d_Loss:0.1912  g_loss:2.5354
# epoch:495  d_Loss:0.2260  g_loss:3.1028
# epoch:496  d_Loss:0.1381  g_loss:3.7231
# epoch:497  d_Loss:0.4479  g_loss:2.5062
# epoch:498  d_Loss:0.3469  g_loss:2.4870
# epoch:499  d_Loss:0.4258  g_loss:3.1120
# epoch:500  d_Loss:0.2573  g_loss:4.5886
# epoch:501  d_Loss:0.4262  g_loss:3.4142
# epoch:502  d_Loss:0.3135  g_loss:2.5656
# epoch:503  d_Loss:0.3583  g_loss:3.4660
# epoch:504  d_Loss:0.3290  g_loss:3.8963
# epoch:505  d_Loss:0.1594  g_loss:4.6804
# epoch:506  d_Loss:0.2977  g_loss:4.1664
# epoch:507  d_Loss:0.2620  g_loss:2.3028
# epoch:508  d_Loss:0.4091  g_loss:1.7392
# epoch:509  d_Loss:0.2797  g_loss:2.2035
# epoch:510  d_Loss:0.1520  g_loss:3.3304
# epoch:511  d_Loss:0.2759  g_loss:2.9072
# epoch:512  d_Loss:0.3245  g_loss:2.5308
# epoch:513  d_Loss:0.3210  g_loss:2.6089
# epoch:514  d_Loss:0.2152  g_loss:2.4654
# epoch:515  d_Loss:0.4524  g_loss:2.5243
# epoch:516  d_Loss:0.1729  g_loss:2.8330
# epoch:517  d_Loss:0.2494  g_loss:3.0853
# epoch:518  d_Loss:0.2059  g_loss:3.0579
# epoch:519  d_Loss:0.1708  g_loss:2.8149
# epoch:520  d_Loss:0.2455  g_loss:2.8831
# epoch:521  d_Loss:0.1840  g_loss:4.0439
# epoch:522  d_Loss:0.2613  g_loss:3.7094
# epoch:523  d_Loss:0.5180  g_loss:1.8652
# epoch:524  d_Loss:0.4460  g_loss:2.5222
# epoch:525  d_Loss:0.2477  g_loss:3.7686
# epoch:526  d_Loss:0.4481  g_loss:2.8192
# epoch:527  d_Loss:0.3197  g_loss:1.9237
# epoch:528  d_Loss:0.4154  g_loss:2.4246
# epoch:529  d_Loss:0.3654  g_loss:2.7848
# epoch:530  d_Loss:0.3146  g_loss:2.7831
# epoch:531  d_Loss:0.4580  g_loss:2.0754
# epoch:532  d_Loss:0.5650  g_loss:1.7894
# epoch:533  d_Loss:0.3599  g_loss:2.6206
# epoch:534  d_Loss:0.2834  g_loss:1.9330
# epoch:535  d_Loss:0.4791  g_loss:1.3360
# epoch:536  d_Loss:0.5011  g_loss:1.6205
# epoch:537  d_Loss:0.2849  g_loss:2.8514
# epoch:538  d_Loss:0.3300  g_loss:2.4814
# epoch:539  d_Loss:0.4635  g_loss:1.6571
# epoch:540  d_Loss:0.3613  g_loss:1.4052
# epoch:541  d_Loss:0.4180  g_loss:1.4410
# epoch:542  d_Loss:0.3415  g_loss:2.2814
# epoch:543  d_Loss:0.3317  g_loss:2.7944
# epoch:544  d_Loss:0.5888  g_loss:2.3368
# epoch:545  d_Loss:0.3807  g_loss:2.1703
# epoch:546  d_Loss:0.4485  g_loss:1.7311
# epoch:547  d_Loss:0.2928  g_loss:1.7349
# epoch:548  d_Loss:0.2684  g_loss:2.0860
# epoch:549  d_Loss:0.6468  g_loss:0.9931
# epoch:550  d_Loss:0.5023  g_loss:1.1728
# epoch:551  d_Loss:0.5612  g_loss:0.9762
# epoch:552  d_Loss:0.4875  g_loss:1.6383
# epoch:553  d_Loss:0.5507  g_loss:1.4264
# epoch:554  d_Loss:0.5018  g_loss:0.9298
# epoch:555  d_Loss:0.5244  g_loss:0.6479
# epoch:556  d_Loss:0.4258  g_loss:1.1444
# epoch:557  d_Loss:0.3960  g_loss:1.2825
# epoch:558  d_Loss:0.4461  g_loss:1.3955
# epoch:559  d_Loss:0.5337  g_loss:1.5183
# epoch:560  d_Loss:0.4536  g_loss:1.3173
# epoch:561  d_Loss:0.4238  g_loss:1.6845
# epoch:562  d_Loss:0.3752  g_loss:2.1954
# epoch:563  d_Loss:0.3275  g_loss:2.6051
# epoch:564  d_Loss:0.2136  g_loss:3.6713
# epoch:565  d_Loss:0.3895  g_loss:3.2353
# epoch:566  d_Loss:0.3553  g_loss:2.6307
# epoch:567  d_Loss:0.4377  g_loss:2.5604
# epoch:568  d_Loss:0.2750  g_loss:3.5060
# epoch:569  d_Loss:0.2924  g_loss:4.1413
# epoch:570  d_Loss:0.5079  g_loss:3.4771
# epoch:571  d_Loss:0.3158  g_loss:2.8997
# epoch:572  d_Loss:0.3583  g_loss:2.7557
# epoch:573  d_Loss:0.3460  g_loss:2.6023
# epoch:574  d_Loss:0.3610  g_loss:2.5812
# epoch:575  d_Loss:0.3651  g_loss:2.9200
# epoch:576  d_Loss:0.3180  g_loss:2.1491
# epoch:577  d_Loss:0.2986  g_loss:2.2058
# epoch:578  d_Loss:0.4740  g_loss:1.3354
# epoch:579  d_Loss:0.5011  g_loss:1.2579
# epoch:580  d_Loss:0.3308  g_loss:1.8688
# epoch:581  d_Loss:0.2864  g_loss:2.0338
# epoch:582  d_Loss:0.4112  g_loss:2.3682
# epoch:583  d_Loss:0.5478  g_loss:2.4397
# epoch:584  d_Loss:0.5414  g_loss:2.3931
# epoch:585  d_Loss:0.2394  g_loss:3.4669
# epoch:586  d_Loss:0.2068  g_loss:3.9663
# epoch:587  d_Loss:0.4192  g_loss:4.0018
# epoch:588  d_Loss:0.3656  g_loss:3.0802
# epoch:589  d_Loss:0.3515  g_loss:3.4882
# epoch:590  d_Loss:0.1732  g_loss:4.7389
# epoch:591  d_Loss:0.3289  g_loss:4.3535
# epoch:592  d_Loss:0.3269  g_loss:3.3767
# epoch:593  d_Loss:0.3969  g_loss:3.2245
# epoch:594  d_Loss:0.6245  g_loss:2.2806
# epoch:595  d_Loss:0.2318  g_loss:2.4511
# epoch:596  d_Loss:0.4616  g_loss:1.7389
# epoch:597  d_Loss:0.8745  g_loss:1.3603
# epoch:598  d_Loss:0.5508  g_loss:2.2508
# epoch:599  d_Loss:0.5789  g_loss:1.5760
# epoch:600  d_Loss:0.5662  g_loss:1.6217
# epoch:601  d_Loss:0.6055  g_loss:1.1351
# epoch:602  d_Loss:0.6690  g_loss:1.3051
# epoch:603  d_Loss:0.4235  g_loss:1.7665
# epoch:604  d_Loss:0.2927  g_loss:2.4323
# epoch:605  d_Loss:0.3740  g_loss:2.5915
# epoch:606  d_Loss:0.5287  g_loss:1.8859
# epoch:607  d_Loss:0.4501  g_loss:1.2940
# epoch:608  d_Loss:0.4283  g_loss:1.6050
# epoch:609  d_Loss:0.4411  g_loss:1.9905
# epoch:610  d_Loss:0.1892  g_loss:2.7125
# epoch:611  d_Loss:0.2176  g_loss:3.5380
# epoch:612  d_Loss:0.2135  g_loss:3.1472
# epoch:613  d_Loss:0.2933  g_loss:2.5061
# epoch:614  d_Loss:0.3474  g_loss:3.1111
# epoch:615  d_Loss:0.2832  g_loss:2.9704
# epoch:616  d_Loss:0.1512  g_loss:2.3156
# epoch:617  d_Loss:0.3337  g_loss:2.7233
# epoch:618  d_Loss:0.2438  g_loss:3.2248
# epoch:619  d_Loss:0.3103  g_loss:3.2150
# epoch:620  d_Loss:0.3465  g_loss:2.7984
# epoch:621  d_Loss:0.6884  g_loss:2.8504
# epoch:622  d_Loss:0.3673  g_loss:2.3503
# epoch:623  d_Loss:0.5504  g_loss:1.6502
# epoch:624  d_Loss:0.4886  g_loss:1.8555
# epoch:625  d_Loss:0.5156  g_loss:1.9846
# epoch:626  d_Loss:0.4850  g_loss:2.0240
# epoch:627  d_Loss:0.6213  g_loss:1.8481
# epoch:628  d_Loss:0.8645  g_loss:1.6111
# epoch:629  d_Loss:0.4967  g_loss:1.6612
# epoch:630  d_Loss:0.3857  g_loss:2.0501
# epoch:631  d_Loss:0.5955  g_loss:1.6394
# epoch:632  d_Loss:0.5201  g_loss:2.1776
# epoch:633  d_Loss:0.3457  g_loss:2.0561
# epoch:634  d_Loss:0.4232  g_loss:1.9523
# epoch:635  d_Loss:0.3074  g_loss:2.7544
# epoch:636  d_Loss:0.2366  g_loss:2.7781
# epoch:637  d_Loss:0.3173  g_loss:2.7627
# epoch:638  d_Loss:0.3041  g_loss:2.9937
# epoch:639  d_Loss:0.2724  g_loss:2.9816
# epoch:640  d_Loss:0.2969  g_loss:3.1641
# epoch:641  d_Loss:0.4536  g_loss:2.7292
# epoch:642  d_Loss:0.2482  g_loss:2.8256
# epoch:643  d_Loss:0.2989  g_loss:2.8606
# epoch:644  d_Loss:0.2462  g_loss:2.6883
# epoch:645  d_Loss:0.5016  g_loss:2.8572
# epoch:646  d_Loss:0.3902  g_loss:3.0584
# epoch:647  d_Loss:0.4965  g_loss:2.4810
# epoch:648  d_Loss:0.5014  g_loss:3.0074
# epoch:649  d_Loss:0.5621  g_loss:2.0101
# epoch:650  d_Loss:0.6573  g_loss:1.8221
# epoch:651  d_Loss:0.6893  g_loss:2.3316
# epoch:652  d_Loss:0.4921  g_loss:1.8267
# epoch:653  d_Loss:0.7537  g_loss:1.5648
# epoch:654  d_Loss:0.6279  g_loss:1.6574
# epoch:655  d_Loss:0.5540  g_loss:1.5416
# epoch:656  d_Loss:0.5075  g_loss:1.5483
# epoch:657  d_Loss:0.5078  g_loss:1.9883
# epoch:658  d_Loss:0.4848  g_loss:2.0177
# epoch:659  d_Loss:0.4381  g_loss:2.3612
# epoch:660  d_Loss:0.4362  g_loss:2.1431
# epoch:661  d_Loss:0.3574  g_loss:2.1446
# epoch:662  d_Loss:0.3167  g_loss:1.7934
# epoch:663  d_Loss:0.2235  g_loss:2.1009
# epoch:664  d_Loss:0.2770  g_loss:2.1925
# epoch:665  d_Loss:0.2850  g_loss:2.0609
# epoch:666  d_Loss:0.1651  g_loss:3.0210
# epoch:667  d_Loss:0.1279  g_loss:3.0544
# epoch:668  d_Loss:0.2466  g_loss:2.7867
# epoch:669  d_Loss:0.2170  g_loss:2.6835
# epoch:670  d_Loss:0.2287  g_loss:2.3468
# epoch:671  d_Loss:0.3106  g_loss:2.5490
# epoch:672  d_Loss:0.2727  g_loss:2.9444
# epoch:673  d_Loss:0.2374  g_loss:2.8518
# epoch:674  d_Loss:0.3633  g_loss:2.1272
# epoch:675  d_Loss:0.4193  g_loss:1.9310
# epoch:676  d_Loss:0.3722  g_loss:1.9013
# epoch:677  d_Loss:0.2371  g_loss:2.0260
# epoch:678  d_Loss:0.3850  g_loss:2.7228
# epoch:679  d_Loss:0.4777  g_loss:1.9142
# epoch:680  d_Loss:0.4378  g_loss:2.4951
# epoch:681  d_Loss:0.5539  g_loss:2.7777
# epoch:682  d_Loss:0.5286  g_loss:2.7868
# epoch:683  d_Loss:0.6098  g_loss:2.6771
# epoch:684  d_Loss:0.5978  g_loss:2.5239
# epoch:685  d_Loss:0.6211  g_loss:2.5475
# epoch:686  d_Loss:0.7284  g_loss:2.6335
# epoch:687  d_Loss:0.6277  g_loss:2.3769
# epoch:688  d_Loss:0.6598  g_loss:1.9521
# epoch:689  d_Loss:0.6191  g_loss:2.1559
# epoch:690  d_Loss:0.5446  g_loss:1.9741
# epoch:691  d_Loss:0.4265  g_loss:2.5003
# epoch:692  d_Loss:0.6106  g_loss:2.8570
# epoch:693  d_Loss:0.6352  g_loss:1.7852
# epoch:694  d_Loss:0.5816  g_loss:1.6079
# epoch:695  d_Loss:0.4317  g_loss:2.0618
# epoch:696  d_Loss:0.3570  g_loss:2.6635
# epoch:697  d_Loss:0.4407  g_loss:2.8887
# epoch:698  d_Loss:0.2986  g_loss:3.0982
# epoch:699  d_Loss:0.4051  g_loss:2.4881
# epoch:700  d_Loss:0.3237  g_loss:2.7480
# epoch:701  d_Loss:0.3719  g_loss:2.2076
# epoch:702  d_Loss:0.3367  g_loss:2.4702
# epoch:703  d_Loss:0.2669  g_loss:2.7812
# epoch:704  d_Loss:0.2857  g_loss:3.6759
# epoch:705  d_Loss:0.2999  g_loss:3.7358
# epoch:706  d_Loss:0.2469  g_loss:3.8298
# epoch:707  d_Loss:0.2398  g_loss:4.1107
# epoch:708  d_Loss:0.4960  g_loss:2.8417
# epoch:709  d_Loss:0.3902  g_loss:2.8967
# epoch:710  d_Loss:0.3255  g_loss:2.5591
# epoch:711  d_Loss:0.4083  g_loss:2.6841
# epoch:712  d_Loss:0.4060  g_loss:2.7651
# epoch:713  d_Loss:0.4957  g_loss:2.9200
# epoch:714  d_Loss:0.5041  g_loss:2.0561
# epoch:715  d_Loss:0.5055  g_loss:1.9136
# epoch:716  d_Loss:0.7287  g_loss:2.3605
# epoch:717  d_Loss:0.5112  g_loss:2.7848
# epoch:718  d_Loss:0.7374  g_loss:1.5104
# epoch:719  d_Loss:0.5846  g_loss:1.5757
# epoch:720  d_Loss:0.4202  g_loss:1.7688
# epoch:721  d_Loss:0.3709  g_loss:2.1084
# epoch:722  d_Loss:0.3197  g_loss:2.5762
# epoch:723  d_Loss:0.3207  g_loss:2.7998
# epoch:724  d_Loss:0.2247  g_loss:2.5103
# epoch:725  d_Loss:0.3064  g_loss:2.6921
# epoch:726  d_Loss:0.2905  g_loss:2.4449
# epoch:727  d_Loss:0.2350  g_loss:2.9426
# epoch:728  d_Loss:0.2315  g_loss:2.1983
# epoch:729  d_Loss:0.1685  g_loss:2.6310
# epoch:730  d_Loss:0.1909  g_loss:2.9209
# epoch:731  d_Loss:0.1435  g_loss:3.3871
# epoch:732  d_Loss:0.1973  g_loss:3.5060
# epoch:733  d_Loss:0.2444  g_loss:3.3408
# epoch:734  d_Loss:0.2513  g_loss:2.9851
# epoch:735  d_Loss:0.2524  g_loss:2.3666
# epoch:736  d_Loss:0.2696  g_loss:3.1314
# epoch:737  d_Loss:0.1410  g_loss:3.6062
# epoch:738  d_Loss:0.3528  g_loss:2.9034
# epoch:739  d_Loss:0.4431  g_loss:2.6868
# epoch:740  d_Loss:0.3650  g_loss:2.6201
# epoch:741  d_Loss:0.4777  g_loss:2.1161
# epoch:742  d_Loss:0.3944  g_loss:2.0562
# epoch:743  d_Loss:0.5707  g_loss:1.5558
# epoch:744  d_Loss:0.4280  g_loss:1.7850
# epoch:745  d_Loss:0.5549  g_loss:1.9225
# epoch:746  d_Loss:0.7718  g_loss:1.3564
# epoch:747  d_Loss:0.8803  g_loss:1.3429
# epoch:748  d_Loss:0.7160  g_loss:1.5772
# epoch:749  d_Loss:0.5722  g_loss:2.2261
# epoch:750  d_Loss:0.4863  g_loss:2.1915
# epoch:751  d_Loss:0.5795  g_loss:1.7187
# epoch:752  d_Loss:0.6642  g_loss:1.5389
# epoch:753  d_Loss:0.6022  g_loss:1.5300
# epoch:754  d_Loss:0.2995  g_loss:2.4542
# epoch:755  d_Loss:0.5383  g_loss:2.6044
# epoch:756  d_Loss:0.3946  g_loss:1.9217
# epoch:757  d_Loss:0.2787  g_loss:2.3208
# epoch:758  d_Loss:0.3704  g_loss:2.7285
# epoch:759  d_Loss:0.3577  g_loss:2.7150
# epoch:760  d_Loss:0.3849  g_loss:2.8257
# epoch:761  d_Loss:0.3292  g_loss:3.2713
# epoch:762  d_Loss:0.3299  g_loss:3.2378
# epoch:763  d_Loss:0.3144  g_loss:3.1795
# epoch:764  d_Loss:0.3860  g_loss:2.5269
# epoch:765  d_Loss:0.1748  g_loss:3.2383
# epoch:766  d_Loss:0.4057  g_loss:2.7584
# epoch:767  d_Loss:0.3192  g_loss:2.5705
# epoch:768  d_Loss:0.2884  g_loss:2.9930
# epoch:769  d_Loss:0.3506  g_loss:3.0631
# epoch:770  d_Loss:0.3241  g_loss:2.6890
# epoch:771  d_Loss:0.3783  g_loss:2.2373
# epoch:772  d_Loss:0.4528  g_loss:1.9808
# epoch:773  d_Loss:0.4349  g_loss:2.3716
# epoch:774  d_Loss:0.5018  g_loss:2.2707
# epoch:775  d_Loss:0.6161  g_loss:2.1955
# epoch:776  d_Loss:0.5008  g_loss:2.5164
# epoch:777  d_Loss:0.4898  g_loss:2.1369
# epoch:778  d_Loss:0.7709  g_loss:1.6415
# epoch:779  d_Loss:0.7176  g_loss:1.2898
# epoch:780  d_Loss:0.5733  g_loss:1.3512
# epoch:781  d_Loss:0.4219  g_loss:1.9305
# epoch:782  d_Loss:0.4657  g_loss:2.0120
# epoch:783  d_Loss:0.7038  g_loss:1.3917
# epoch:784  d_Loss:0.4831  g_loss:1.3524
# epoch:785  d_Loss:0.4339  g_loss:1.5502
# epoch:786  d_Loss:0.4616  g_loss:1.9243
# epoch:787  d_Loss:0.5175  g_loss:1.7941
# epoch:788  d_Loss:0.3893  g_loss:2.1725
# epoch:789  d_Loss:0.4063  g_loss:1.8112
# epoch:790  d_Loss:0.3189  g_loss:2.1492
# epoch:791  d_Loss:0.3582  g_loss:2.2871
# epoch:792  d_Loss:0.3390  g_loss:2.2362
# epoch:793  d_Loss:0.3608  g_loss:2.3271
# epoch:794  d_Loss:0.2956  g_loss:2.7157
# epoch:795  d_Loss:0.2249  g_loss:2.2854
# epoch:796  d_Loss:0.3974  g_loss:2.2063
# epoch:797  d_Loss:0.2750  g_loss:2.6543
# epoch:798  d_Loss:0.3418  g_loss:2.8273
# epoch:799  d_Loss:0.3248  g_loss:2.8912
# epoch:800  d_Loss:0.2995  g_loss:3.3161
# epoch:801  d_Loss:0.4601  g_loss:2.0734
# epoch:802  d_Loss:0.3400  g_loss:2.3476
# epoch:803  d_Loss:0.4635  g_loss:1.5341
# epoch:804  d_Loss:0.3461  g_loss:2.1713
# epoch:805  d_Loss:0.2545  g_loss:3.0248
# epoch:806  d_Loss:0.6304  g_loss:1.9781
# epoch:807  d_Loss:0.5883  g_loss:1.2997
# epoch:808  d_Loss:0.6937  g_loss:1.4986
# epoch:809  d_Loss:0.7513  g_loss:1.4138
# epoch:810  d_Loss:0.5347  g_loss:1.9508
# epoch:811  d_Loss:0.5343  g_loss:2.4701
# epoch:812  d_Loss:0.5943  g_loss:1.7645
# epoch:813  d_Loss:0.6771  g_loss:1.3401
# epoch:814  d_Loss:0.6624  g_loss:1.1023
# epoch:815  d_Loss:0.8224  g_loss:1.1295
# epoch:816  d_Loss:0.6192  g_loss:1.6283
# epoch:817  d_Loss:0.4946  g_loss:1.8978
# epoch:818  d_Loss:0.4617  g_loss:2.5216
# epoch:819  d_Loss:0.5762  g_loss:1.9366
# epoch:820  d_Loss:0.5777  g_loss:1.0615
# epoch:821  d_Loss:0.3757  g_loss:1.2879
# epoch:822  d_Loss:0.3663  g_loss:1.9072
# epoch:823  d_Loss:0.2960  g_loss:1.7372
# epoch:824  d_Loss:0.3206  g_loss:1.9422
# epoch:825  d_Loss:0.2573  g_loss:2.3760
# epoch:826  d_Loss:0.2708  g_loss:2.0879
# epoch:827  d_Loss:0.1762  g_loss:2.6201
# epoch:828  d_Loss:0.2941  g_loss:2.0484
# epoch:829  d_Loss:0.2937  g_loss:2.3249
# epoch:830  d_Loss:0.4136  g_loss:2.2430
# epoch:831  d_Loss:0.3226  g_loss:2.1751
# epoch:832  d_Loss:0.3175  g_loss:2.0955
# epoch:833  d_Loss:0.3151  g_loss:2.5684
# epoch:834  d_Loss:0.3208  g_loss:3.1509
# epoch:835  d_Loss:0.4892  g_loss:2.1056
# epoch:836  d_Loss:0.4355  g_loss:2.6961
# epoch:837  d_Loss:0.3287  g_loss:1.8540
# epoch:838  d_Loss:0.5848  g_loss:2.2828
# epoch:839  d_Loss:0.3960  g_loss:2.2582
# epoch:840  d_Loss:0.4923  g_loss:2.4052
# epoch:841  d_Loss:0.3989  g_loss:2.3228
# epoch:842  d_Loss:0.4929  g_loss:2.0960
# epoch:843  d_Loss:0.5660  g_loss:1.5730
# epoch:844  d_Loss:0.5894  g_loss:1.9580
# epoch:845  d_Loss:0.6014  g_loss:2.2719
# epoch:846  d_Loss:0.5949  g_loss:2.2495
# epoch:847  d_Loss:0.7032  g_loss:1.7094
# epoch:848  d_Loss:0.7183  g_loss:1.4009
# epoch:849  d_Loss:0.7906  g_loss:1.5281
# epoch:850  d_Loss:0.5025  g_loss:2.0474
# epoch:851  d_Loss:0.6930  g_loss:1.9596
# epoch:852  d_Loss:0.5966  g_loss:1.8660
# epoch:853  d_Loss:0.6613  g_loss:1.4805
# epoch:854  d_Loss:0.5606  g_loss:1.1267
# epoch:855  d_Loss:0.5801  g_loss:1.1562
# epoch:856  d_Loss:0.4166  g_loss:1.9030
# epoch:857  d_Loss:0.3241  g_loss:2.7305
# epoch:858  d_Loss:0.3177  g_loss:2.0115
# epoch:859  d_Loss:0.3609  g_loss:2.7047
# epoch:860  d_Loss:0.3773  g_loss:2.0720
# epoch:861  d_Loss:0.3399  g_loss:2.1211
# epoch:862  d_Loss:0.2908  g_loss:2.2901
# epoch:863  d_Loss:0.3350  g_loss:1.9121
# epoch:864  d_Loss:0.1713  g_loss:3.0589
# epoch:865  d_Loss:0.3177  g_loss:2.4718
# epoch:866  d_Loss:0.3762  g_loss:2.2787
# epoch:867  d_Loss:0.2646  g_loss:2.7841
# epoch:868  d_Loss:0.3036  g_loss:2.3256
# epoch:869  d_Loss:0.3001  g_loss:2.5754
# epoch:870  d_Loss:0.3182  g_loss:2.0632
# epoch:871  d_Loss:0.2930  g_loss:2.4013
# epoch:872  d_Loss:0.4106  g_loss:2.4375
# epoch:873  d_Loss:0.2621  g_loss:3.1508
# epoch:874  d_Loss:0.3893  g_loss:2.5305
# epoch:875  d_Loss:0.3993  g_loss:1.8105
# epoch:876  d_Loss:0.4173  g_loss:2.4273
# epoch:877  d_Loss:0.6416  g_loss:2.0293
# epoch:878  d_Loss:0.4523  g_loss:2.2859
# epoch:879  d_Loss:0.4673  g_loss:2.0090
# epoch:880  d_Loss:0.7628  g_loss:1.3615
# epoch:881  d_Loss:0.6835  g_loss:1.4459
# epoch:882  d_Loss:0.5742  g_loss:1.6172
# epoch:883  d_Loss:0.6303  g_loss:1.8719
# epoch:884  d_Loss:0.6532  g_loss:1.3677
# epoch:885  d_Loss:0.6703  g_loss:1.6928
# epoch:886  d_Loss:0.4628  g_loss:1.3927
# epoch:887  d_Loss:0.5293  g_loss:1.9334
# epoch:888  d_Loss:0.4434  g_loss:2.0088
# epoch:889  d_Loss:0.5098  g_loss:1.8905
# epoch:890  d_Loss:0.6332  g_loss:1.5728
# epoch:891  d_Loss:0.5645  g_loss:1.4561
# epoch:892  d_Loss:0.7013  g_loss:1.3400
# epoch:893  d_Loss:0.4047  g_loss:1.6602
# epoch:894  d_Loss:0.4598  g_loss:2.0608
# epoch:895  d_Loss:0.5727  g_loss:1.6938
# epoch:896  d_Loss:0.4321  g_loss:1.7543
# epoch:897  d_Loss:0.3583  g_loss:1.8734
# epoch:898  d_Loss:0.4262  g_loss:1.6443
# epoch:899  d_Loss:0.4609  g_loss:1.6463
# epoch:900  d_Loss:0.3303  g_loss:2.0662
# epoch:901  d_Loss:0.3222  g_loss:2.2291
# epoch:902  d_Loss:0.4565  g_loss:2.2320
# epoch:903  d_Loss:0.2543  g_loss:2.6840
# epoch:904  d_Loss:0.2287  g_loss:2.3674
# epoch:905  d_Loss:0.2500  g_loss:2.4887
# epoch:906  d_Loss:0.2426  g_loss:3.2301
# epoch:907  d_Loss:0.2331  g_loss:3.2668
# epoch:908  d_Loss:0.3104  g_loss:3.4025
# epoch:909  d_Loss:0.2557  g_loss:3.3234
# epoch:910  d_Loss:0.3720  g_loss:2.4524
# epoch:911  d_Loss:0.2383  g_loss:2.8456
# epoch:912  d_Loss:0.4126  g_loss:2.5707
# epoch:913  d_Loss:0.1702  g_loss:3.6511
# epoch:914  d_Loss:0.4289  g_loss:2.9944
# epoch:915  d_Loss:0.3179  g_loss:2.8943
# epoch:916  d_Loss:0.5518  g_loss:2.0562
# epoch:917  d_Loss:0.6106  g_loss:1.7991
# epoch:918  d_Loss:0.7311  g_loss:1.8466
# epoch:919  d_Loss:0.6369  g_loss:2.3142
# epoch:920  d_Loss:0.5713  g_loss:2.2159
# epoch:921  d_Loss:0.6264  g_loss:1.5944
# epoch:922  d_Loss:0.6733  g_loss:1.3726
# epoch:923  d_Loss:0.6731  g_loss:1.2579
# epoch:924  d_Loss:0.6201  g_loss:1.5497
# epoch:925  d_Loss:0.6891  g_loss:1.6320
# epoch:926  d_Loss:0.6094  g_loss:1.7315
# epoch:927  d_Loss:0.4170  g_loss:1.8076
# epoch:928  d_Loss:0.4308  g_loss:2.1677
# epoch:929  d_Loss:0.5640  g_loss:1.4921
# epoch:930  d_Loss:0.3430  g_loss:2.0278
# epoch:931  d_Loss:0.4118  g_loss:2.0129
# epoch:932  d_Loss:0.4233  g_loss:1.6625
# epoch:933  d_Loss:0.3808  g_loss:1.9896
# epoch:934  d_Loss:0.3312  g_loss:2.3703
# epoch:935  d_Loss:0.3412  g_loss:2.5070
# epoch:936  d_Loss:0.4039  g_loss:1.8865
# epoch:937  d_Loss:0.3100  g_loss:2.2978
# epoch:938  d_Loss:0.2081  g_loss:2.4388
# epoch:939  d_Loss:0.2668  g_loss:2.3587
# epoch:940  d_Loss:0.2413  g_loss:2.7177
# epoch:941  d_Loss:0.2383  g_loss:3.2643
# epoch:942  d_Loss:0.2729  g_loss:3.0506
# epoch:943  d_Loss:0.2738  g_loss:2.2231
# epoch:944  d_Loss:0.2370  g_loss:2.6862
# epoch:945  d_Loss:0.2452  g_loss:2.7834
# epoch:946  d_Loss:0.2551  g_loss:2.9215
# epoch:947  d_Loss:0.2481  g_loss:3.5010
# epoch:948  d_Loss:0.3528  g_loss:2.5026
# epoch:949  d_Loss:0.3901  g_loss:2.7811
# epoch:950  d_Loss:0.2572  g_loss:3.4561
# epoch:951  d_Loss:0.3656  g_loss:2.3426
# epoch:952  d_Loss:0.5876  g_loss:2.2505
# epoch:953  d_Loss:0.3812  g_loss:2.4927
# epoch:954  d_Loss:0.5663  g_loss:2.7588
# epoch:955  d_Loss:0.7254  g_loss:2.4958
# epoch:956  d_Loss:0.8608  g_loss:2.2121
# epoch:957  d_Loss:0.8033  g_loss:1.5967
# epoch:958  d_Loss:0.7124  g_loss:1.2011
# epoch:959  d_Loss:0.7105  g_loss:1.1563
# epoch:960  d_Loss:0.6889  g_loss:1.6067
# epoch:961  d_Loss:0.5175  g_loss:2.1762
# epoch:962  d_Loss:0.5688  g_loss:2.3960
# epoch:963  d_Loss:0.8592  g_loss:1.3420
# epoch:964  d_Loss:0.6736  g_loss:1.0780
# epoch:965  d_Loss:0.7704  g_loss:1.2768
# epoch:966  d_Loss:0.4371  g_loss:1.8198
# epoch:967  d_Loss:0.3701  g_loss:2.0090
# epoch:968  d_Loss:0.4600  g_loss:1.9097
# epoch:969  d_Loss:0.3742  g_loss:2.1759
# epoch:970  d_Loss:0.4047  g_loss:1.8182
# epoch:971  d_Loss:0.3273  g_loss:1.9050
# epoch:972  d_Loss:0.3257  g_loss:2.4479
# epoch:973  d_Loss:0.3329  g_loss:2.4967
# epoch:974  d_Loss:0.4580  g_loss:2.1706
# epoch:975  d_Loss:0.2864  g_loss:2.6312
# epoch:976  d_Loss:0.3000  g_loss:2.4590
# epoch:977  d_Loss:0.3280  g_loss:2.5558
# epoch:978  d_Loss:0.2846  g_loss:2.2128
# epoch:979  d_Loss:0.3586  g_loss:2.2104
# epoch:980  d_Loss:0.2758  g_loss:2.1622
# epoch:981  d_Loss:0.4155  g_loss:1.9925
# epoch:982  d_Loss:0.4108  g_loss:2.4699
# epoch:983  d_Loss:0.4291  g_loss:2.7230
# epoch:984  d_Loss:0.3858  g_loss:2.6852
# epoch:985  d_Loss:0.4177  g_loss:2.9439
# epoch:986  d_Loss:0.4190  g_loss:2.3898
# epoch:987  d_Loss:0.3504  g_loss:2.5842
# epoch:988  d_Loss:0.4905  g_loss:2.1000
# epoch:989  d_Loss:0.4838  g_loss:1.7853
# epoch:990  d_Loss:0.5246  g_loss:1.2939
# epoch:991  d_Loss:0.4216  g_loss:2.0356
# epoch:992  d_Loss:0.3171  g_loss:2.8000
# epoch:993  d_Loss:0.5660  g_loss:1.5770
# epoch:994  d_Loss:0.8484  g_loss:1.1917
# epoch:995  d_Loss:0.5735  g_loss:1.2333
# epoch:996  d_Loss:0.6034  g_loss:1.4333
# epoch:997  d_Loss:0.4860  g_loss:1.5019
# epoch:998  d_Loss:0.6242  g_loss:1.5729
# epoch:999  d_Loss:0.5193  g_loss:1.4395
# epoch:1000  d_Loss:0.6537  g_loss:1.3305
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# epoch:1001  d_Loss:0.4518  g_loss:1.6927
# epoch:1002  d_Loss:0.5171  g_loss:1.5150
# epoch:1003  d_Loss:0.4035  g_loss:1.7894
# epoch:1004  d_Loss:0.5768  g_loss:1.9461
# epoch:1005  d_Loss:0.4729  g_loss:1.9878
# epoch:1006  d_Loss:0.3706  g_loss:1.8308
# epoch:1007  d_Loss:0.3867  g_loss:2.0646
# epoch:1008  d_Loss:0.3189  g_loss:1.7158
# epoch:1009  d_Loss:0.4982  g_loss:1.8826
# epoch:1010  d_Loss:0.2854  g_loss:2.1285
# epoch:1011  d_Loss:0.3249  g_loss:2.1584
# epoch:1012  d_Loss:0.3693  g_loss:2.2314
# epoch:1013  d_Loss:0.3644  g_loss:2.2098
# epoch:1014  d_Loss:0.3089  g_loss:2.7732
# epoch:1015  d_Loss:0.3052  g_loss:2.5483
# epoch:1016  d_Loss:0.3558  g_loss:2.5326
# epoch:1017  d_Loss:0.4428  g_loss:1.9525
# epoch:1018  d_Loss:0.4945  g_loss:1.6712
# epoch:1019  d_Loss:0.2958  g_loss:2.0596
# epoch:1020  d_Loss:0.2883  g_loss:2.8694
# epoch:1021  d_Loss:0.3547  g_loss:3.1523
# epoch:1022  d_Loss:0.4575  g_loss:2.1921
# epoch:1023  d_Loss:0.4633  g_loss:1.7464
# epoch:1024  d_Loss:0.5223  g_loss:1.3964
# epoch:1025  d_Loss:0.3754  g_loss:1.8545
# epoch:1026  d_Loss:0.4034  g_loss:1.9184
# epoch:1027  d_Loss:0.4358  g_loss:2.5883
# epoch:1028  d_Loss:0.4377  g_loss:3.0547
# epoch:1029  d_Loss:0.4523  g_loss:2.2101
# epoch:1030  d_Loss:0.4831  g_loss:2.2551
# epoch:1031  d_Loss:0.5314  g_loss:1.9159
# epoch:1032  d_Loss:0.4714  g_loss:1.8505
# epoch:1033  d_Loss:0.5044  g_loss:1.9386
# epoch:1034  d_Loss:0.4730  g_loss:2.5250
# epoch:1035  d_Loss:0.5731  g_loss:2.0710
# epoch:1036  d_Loss:0.7694  g_loss:1.7517
# epoch:1037  d_Loss:0.5921  g_loss:1.3411
# epoch:1038  d_Loss:0.5213  g_loss:1.5857
# epoch:1039  d_Loss:0.6088  g_loss:1.5912
# epoch:1040  d_Loss:0.4800  g_loss:1.6025
# epoch:1041  d_Loss:0.4551  g_loss:1.8598
# epoch:1042  d_Loss:0.4098  g_loss:1.9176
# epoch:1043  d_Loss:0.5523  g_loss:1.5905
# epoch:1044  d_Loss:0.6341  g_loss:1.5570
# epoch:1045  d_Loss:0.4850  g_loss:1.3942
# epoch:1046  d_Loss:0.4437  g_loss:1.6262
# epoch:1047  d_Loss:0.2955  g_loss:2.3116
# epoch:1048  d_Loss:0.3427  g_loss:2.8622
# epoch:1049  d_Loss:0.4722  g_loss:2.2462
# epoch:1050  d_Loss:0.3271  g_loss:2.0414
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# epoch:1051  d_Loss:0.3407  g_loss:2.1880
# epoch:1052  d_Loss:0.3545  g_loss:1.8885
# epoch:1053  d_Loss:0.3258  g_loss:1.9818
# epoch:1054  d_Loss:0.2334  g_loss:2.3343
# epoch:1055  d_Loss:0.3432  g_loss:2.5658
# epoch:1056  d_Loss:0.2591  g_loss:2.7120
# epoch:1057  d_Loss:0.3467  g_loss:2.5906
# epoch:1058  d_Loss:0.3715  g_loss:2.1750
# epoch:1059  d_Loss:0.4174  g_loss:2.6483
# epoch:1060  d_Loss:0.2784  g_loss:2.2052
# epoch:1061  d_Loss:0.4142  g_loss:1.7653
# epoch:1062  d_Loss:0.2854  g_loss:2.5593
# epoch:1063  d_Loss:0.4391  g_loss:2.4701
# epoch:1064  d_Loss:0.5554  g_loss:2.3261
# epoch:1065  d_Loss:0.3860  g_loss:2.3062
# epoch:1066  d_Loss:0.4576  g_loss:1.6436
# epoch:1067  d_Loss:0.3620  g_loss:1.8074
# epoch:1068  d_Loss:0.6822  g_loss:1.9626
# epoch:1069  d_Loss:0.7453  g_loss:2.0087
# epoch:1070  d_Loss:0.5598  g_loss:2.4047
# epoch:1071  d_Loss:0.6235  g_loss:2.2286
# epoch:1072  d_Loss:0.5841  g_loss:2.1723
# epoch:1073  d_Loss:0.7706  g_loss:1.5049
# epoch:1074  d_Loss:0.6817  g_loss:1.2672
# epoch:1075  d_Loss:0.4708  g_loss:1.7466
# epoch:1076  d_Loss:0.5929  g_loss:1.8044
# epoch:1077  d_Loss:0.4828  g_loss:2.1397
# epoch:1078  d_Loss:0.5226  g_loss:2.0455
# epoch:1079  d_Loss:0.4048  g_loss:1.7317
# epoch:1080  d_Loss:0.4375  g_loss:1.8057
# epoch:1081  d_Loss:0.4217  g_loss:1.9064
# epoch:1082  d_Loss:0.3979  g_loss:1.9550
# epoch:1083  d_Loss:0.3275  g_loss:2.4306
# epoch:1084  d_Loss:0.5276  g_loss:2.0804
# epoch:1085  d_Loss:0.4003  g_loss:2.1870
# epoch:1086  d_Loss:0.4776  g_loss:1.9323
# epoch:1087  d_Loss:0.3736  g_loss:1.5547
# epoch:1088  d_Loss:0.5200  g_loss:1.2192
# epoch:1089  d_Loss:0.2269  g_loss:1.7786
# epoch:1090  d_Loss:0.3902  g_loss:2.0972
# epoch:1091  d_Loss:0.3863  g_loss:2.1645
# epoch:1092  d_Loss:0.4183  g_loss:2.1628
# epoch:1093  d_Loss:0.3001  g_loss:2.0376
# epoch:1094  d_Loss:0.3869  g_loss:1.9325
# epoch:1095  d_Loss:0.5113  g_loss:1.9503
# epoch:1096  d_Loss:0.5164  g_loss:1.9022
# epoch:1097  d_Loss:0.5252  g_loss:1.6687
# epoch:1098  d_Loss:0.4818  g_loss:1.7417
# epoch:1099  d_Loss:0.3467  g_loss:1.7109
# epoch:1100  d_Loss:0.3722  g_loss:1.9699
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# epoch:1101  d_Loss:0.5236  g_loss:1.7564
# epoch:1102  d_Loss:0.4435  g_loss:2.0869
# epoch:1103  d_Loss:0.5864  g_loss:1.1489
# epoch:1104  d_Loss:0.4513  g_loss:1.0980
# epoch:1105  d_Loss:0.4986  g_loss:1.1450
# epoch:1106  d_Loss:0.4299  g_loss:1.5299
# epoch:1107  d_Loss:0.5365  g_loss:1.8086
# epoch:1108  d_Loss:0.5619  g_loss:1.6825
# epoch:1109  d_Loss:0.5446  g_loss:1.4433
# epoch:1110  d_Loss:0.4870  g_loss:1.1499
# epoch:1111  d_Loss:0.5321  g_loss:1.5599
# epoch:1112  d_Loss:0.4769  g_loss:1.6327
# epoch:1113  d_Loss:0.3999  g_loss:1.9773
# epoch:1114  d_Loss:0.4058  g_loss:2.1523
# epoch:1115  d_Loss:0.5742  g_loss:1.9628
# epoch:1116  d_Loss:0.3879  g_loss:1.8214
# epoch:1117  d_Loss:0.3926  g_loss:1.9272
# epoch:1118  d_Loss:0.4018  g_loss:1.9634
# epoch:1119  d_Loss:0.4542  g_loss:2.5034
# epoch:1120  d_Loss:0.2781  g_loss:2.5041
# epoch:1121  d_Loss:0.4383  g_loss:2.2775
# epoch:1122  d_Loss:0.4215  g_loss:2.2465
# epoch:1123  d_Loss:0.4581  g_loss:2.1183
# epoch:1124  d_Loss:0.4441  g_loss:1.8112
# epoch:1125  d_Loss:0.5654  g_loss:2.0923
# epoch:1126  d_Loss:0.3772  g_loss:2.1636
# epoch:1127  d_Loss:0.3602  g_loss:2.3924
# epoch:1128  d_Loss:0.4281  g_loss:1.6752
# epoch:1129  d_Loss:0.5224  g_loss:2.0120
# epoch:1130  d_Loss:0.6311  g_loss:1.8948
# epoch:1131  d_Loss:0.4804  g_loss:1.3535
# epoch:1132  d_Loss:0.5572  g_loss:1.4754
# epoch:1133  d_Loss:0.5058  g_loss:1.7195
# epoch:1134  d_Loss:0.3853  g_loss:2.2470
# epoch:1135  d_Loss:0.4856  g_loss:2.1616
# epoch:1136  d_Loss:0.4994  g_loss:1.7079
# epoch:1137  d_Loss:0.4913  g_loss:1.8993
# epoch:1138  d_Loss:0.4460  g_loss:1.6638
# epoch:1139  d_Loss:0.4803  g_loss:2.3824
# epoch:1140  d_Loss:0.4931  g_loss:2.2032
# epoch:1141  d_Loss:0.4374  g_loss:1.9557
# epoch:1142  d_Loss:0.5091  g_loss:1.3623
# epoch:1143  d_Loss:0.5496  g_loss:1.6426
# epoch:1144  d_Loss:0.5590  g_loss:1.5538
# epoch:1145  d_Loss:0.5945  g_loss:2.0513
# epoch:1146  d_Loss:0.3335  g_loss:2.6109
# epoch:1147  d_Loss:0.6497  g_loss:2.0031
# epoch:1148  d_Loss:0.4891  g_loss:1.6365
# epoch:1149  d_Loss:0.4931  g_loss:1.3785
# epoch:1150  d_Loss:0.4661  g_loss:1.8596
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# epoch:1151  d_Loss:0.3762  g_loss:2.3262
# epoch:1152  d_Loss:0.4560  g_loss:2.0440
# epoch:1153  d_Loss:0.5198  g_loss:1.4651
# epoch:1154  d_Loss:0.5520  g_loss:1.6171
# epoch:1155  d_Loss:0.5402  g_loss:1.8356
# epoch:1156  d_Loss:0.5055  g_loss:1.5627
# epoch:1157  d_Loss:0.5159  g_loss:1.8228
# epoch:1158  d_Loss:0.5856  g_loss:1.5790
# epoch:1159  d_Loss:0.5312  g_loss:1.4620
# epoch:1160  d_Loss:0.4611  g_loss:1.9057
# epoch:1161  d_Loss:0.4747  g_loss:1.7998
# epoch:1162  d_Loss:0.5603  g_loss:1.6396
# epoch:1163  d_Loss:0.5767  g_loss:1.2075
# ...
# epoch:3669  d_Loss:0.5703  g_loss:1.5267
# epoch:3670  d_Loss:0.7424  g_loss:1.3915
# epoch:3671  d_Loss:0.6623  g_loss:1.3024
# epoch:3672  d_Loss:0.5252  g_loss:1.3005
# epoch:3673  d_Loss:0.6592  g_loss:1.2678
# epoch:3674  d_Loss:0.6287  g_loss:1.2511
# epoch:3675  d_Loss:0.5809  g_loss:1.3456
# epoch:3676  d_Loss:0.5478  g_loss:1.5582
# epoch:3677  d_Loss:0.5660  g_loss:1.7437
# epoch:3678  d_Loss:0.5027  g_loss:1.7918
# epoch:3679  d_Loss:0.4544  g_loss:1.7310
# epoch:3680  d_Loss:0.5259  g_loss:1.7831
# epoch:3681  d_Loss:0.5530  g_loss:1.2450
# epoch:3682  d_Loss:0.3999  g_loss:1.4427
# epoch:3683  d_Loss:0.4876  g_loss:1.5354
# epoch:3684  d_Loss:0.6272  g_loss:1.5162
# epoch:3685  d_Loss:0.4190  g_loss:1.7371
# epoch:3686  d_Loss:0.4025  g_loss:1.8626
# epoch:3687  d_Loss:0.5050  g_loss:1.7041
# epoch:3688  d_Loss:0.6644  g_loss:1.5004
# epoch:3689  d_Loss:0.5628  g_loss:1.4663
# epoch:3690  d_Loss:0.6205  g_loss:1.3061
# epoch:3691  d_Loss:0.6187  g_loss:1.3616
# epoch:3692  d_Loss:0.6417  g_loss:1.4184
# epoch:3693  d_Loss:0.6031  g_loss:1.5322
# epoch:3694  d_Loss:0.4929  g_loss:1.5535
# epoch:3695  d_Loss:0.5852  g_loss:1.0701
# epoch:3696  d_Loss:0.5911  g_loss:1.3580
# epoch:3697  d_Loss:0.5197  g_loss:1.2656
# epoch:3698  d_Loss:0.6597  g_loss:1.2103
# epoch:3699  d_Loss:0.6462  g_loss:1.0355
# epoch:3700  d_Loss:0.4921  g_loss:0.9918
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# epoch:3701  d_Loss:0.6363  g_loss:0.9351
# epoch:3702  d_Loss:0.4986  g_loss:1.4774
# epoch:3703  d_Loss:0.5130  g_loss:1.6681
# epoch:3704  d_Loss:0.6774  g_loss:1.2041
# epoch:3705  d_Loss:0.4549  g_loss:1.6005
# epoch:3706  d_Loss:0.4873  g_loss:1.3809
# epoch:3707  d_Loss:0.5370  g_loss:1.5109
# epoch:3708  d_Loss:0.4255  g_loss:1.5189
# epoch:3709  d_Loss:0.4987  g_loss:1.3398
# epoch:3710  d_Loss:0.4402  g_loss:1.6492
# epoch:3711  d_Loss:0.5499  g_loss:1.6210
# epoch:3712  d_Loss:0.5575  g_loss:1.4834
# epoch:3713  d_Loss:0.4311  g_loss:1.5878
# epoch:3714  d_Loss:0.4811  g_loss:1.4671
# epoch:3715  d_Loss:0.3535  g_loss:1.6550
# epoch:3716  d_Loss:0.4046  g_loss:1.9383
# epoch:3717  d_Loss:0.4832  g_loss:1.5186
# epoch:3718  d_Loss:0.5034  g_loss:1.7184
# epoch:3719  d_Loss:0.4419  g_loss:1.7418
# epoch:3720  d_Loss:0.4696  g_loss:1.5089
# epoch:3721  d_Loss:0.5172  g_loss:1.4046
# epoch:3722  d_Loss:0.4314  g_loss:1.7201
# epoch:3723  d_Loss:0.4108  g_loss:1.5399
# epoch:3724  d_Loss:0.4791  g_loss:1.4161
# epoch:3725  d_Loss:0.6081  g_loss:1.2393
# epoch:3726  d_Loss:0.4779  g_loss:1.5998
# epoch:3727  d_Loss:0.6035  g_loss:1.4659
# epoch:3728  d_Loss:0.4815  g_loss:1.5629
# epoch:3729  d_Loss:0.4733  g_loss:1.4890
# epoch:3730  d_Loss:0.5915  g_loss:1.3589
# epoch:3731  d_Loss:0.4777  g_loss:1.5574
# epoch:3732  d_Loss:0.6100  g_loss:1.1918
# epoch:3733  d_Loss:0.5378  g_loss:1.0423
# epoch:3734  d_Loss:0.5179  g_loss:1.6939
# epoch:3735  d_Loss:0.4778  g_loss:2.1096
# epoch:3736  d_Loss:0.5449  g_loss:1.7986
# epoch:3737  d_Loss:0.7116  g_loss:1.1134
# epoch:3738  d_Loss:0.5611  g_loss:1.2981
# epoch:3739  d_Loss:0.5640  g_loss:1.1730
# epoch:3740  d_Loss:0.5689  g_loss:1.3819
# epoch:3741  d_Loss:0.4630  g_loss:1.5214
# epoch:3742  d_Loss:0.4040  g_loss:1.8061
# epoch:3743  d_Loss:0.5506  g_loss:1.7137
# epoch:3744  d_Loss:0.5908  g_loss:1.7691
# epoch:3745  d_Loss:0.5093  g_loss:1.3283
# epoch:3746  d_Loss:0.6006  g_loss:1.9034
# epoch:3747  d_Loss:0.5788  g_loss:1.2624
# epoch:3748  d_Loss:0.5165  g_loss:1.5076
# epoch:3749  d_Loss:0.4522  g_loss:1.5078
# epoch:3750  d_Loss:0.5202  g_loss:1.6497
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# epoch:3751  d_Loss:0.5162  g_loss:1.4029
# epoch:3752  d_Loss:0.4445  g_loss:1.6841
# epoch:3753  d_Loss:0.5427  g_loss:1.4030
# epoch:3754  d_Loss:0.5101  g_loss:1.4702
# epoch:3755  d_Loss:0.5185  g_loss:1.5631
# epoch:3756  d_Loss:0.5037  g_loss:1.6244
# epoch:3757  d_Loss:0.4990  g_loss:1.8013
# epoch:3758  d_Loss:0.3765  g_loss:1.7853
# epoch:3759  d_Loss:0.5702  g_loss:1.8571
# epoch:3760  d_Loss:0.5161  g_loss:1.2441
# epoch:3761  d_Loss:0.5289  g_loss:1.5909
# epoch:3762  d_Loss:0.5894  g_loss:1.4282
# epoch:3763  d_Loss:0.5443  g_loss:1.9568
# epoch:3764  d_Loss:0.5943  g_loss:1.5607
# epoch:3765  d_Loss:0.5270  g_loss:1.5298
# epoch:3766  d_Loss:0.5385  g_loss:1.1458
# epoch:3767  d_Loss:0.5871  g_loss:1.1769
# epoch:3768  d_Loss:0.6966  g_loss:0.9206
# epoch:3769  d_Loss:0.4885  g_loss:1.4999
# epoch:3770  d_Loss:0.5391  g_loss:1.5530
# epoch:3771  d_Loss:0.5351  g_loss:2.0361
# epoch:3772  d_Loss:0.6517  g_loss:1.9872
# epoch:3773  d_Loss:0.5960  g_loss:1.7055
# epoch:3774  d_Loss:0.5467  g_loss:1.4620
# epoch:3775  d_Loss:0.7108  g_loss:1.3913
# epoch:3776  d_Loss:0.5179  g_loss:1.1806
# epoch:3777  d_Loss:0.5092  g_loss:1.6460
# epoch:3778  d_Loss:0.5337  g_loss:1.6298
# epoch:3779  d_Loss:0.7379  g_loss:1.7646
# epoch:3780  d_Loss:0.6022  g_loss:1.5880
# epoch:3781  d_Loss:0.6809  g_loss:1.3047
# epoch:3782  d_Loss:0.5165  g_loss:1.4579
# epoch:3783  d_Loss:0.5882  g_loss:1.5887
# epoch:3784  d_Loss:0.5437  g_loss:1.7454
# epoch:3785  d_Loss:0.5527  g_loss:1.3584
# epoch:3786  d_Loss:0.5402  g_loss:1.7434
# epoch:3787  d_Loss:0.6013  g_loss:1.3367
# epoch:3788  d_Loss:0.5007  g_loss:1.5648
# epoch:3789  d_Loss:0.4227  g_loss:1.8142
# epoch:3790  d_Loss:0.5348  g_loss:1.5890
# epoch:3791  d_Loss:0.6348  g_loss:1.7954
# epoch:3792  d_Loss:0.5516  g_loss:1.6216
# epoch:3793  d_Loss:0.4547  g_loss:2.3044
# epoch:3794  d_Loss:0.4577  g_loss:1.8947
# epoch:3795  d_Loss:0.3795  g_loss:1.7635
# epoch:3796  d_Loss:0.5736  g_loss:1.4179
# epoch:3797  d_Loss:0.5748  g_loss:1.2713
# epoch:3798  d_Loss:0.4448  g_loss:1.9390
# epoch:3799  d_Loss:0.4907  g_loss:2.1654
# epoch:3800  d_Loss:0.6875  g_loss:1.7589
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# epoch:3801  d_Loss:0.6368  g_loss:1.4086
# epoch:3802  d_Loss:0.5293  g_loss:1.3427
# epoch:3803  d_Loss:0.4929  g_loss:1.1564
# epoch:3804  d_Loss:0.6036  g_loss:1.1850
# epoch:3805  d_Loss:0.6758  g_loss:1.1740
# epoch:3806  d_Loss:0.4190  g_loss:1.9571
# epoch:3807  d_Loss:0.6151  g_loss:1.4092
# epoch:3808  d_Loss:0.7701  g_loss:1.1413
# epoch:3809  d_Loss:0.6332  g_loss:1.2022
# epoch:3810  d_Loss:0.6295  g_loss:0.9645
# epoch:3811  d_Loss:0.6033  g_loss:1.2441
# epoch:3812  d_Loss:0.4491  g_loss:1.6167
# epoch:3813  d_Loss:0.6677  g_loss:1.4977
# epoch:3814  d_Loss:0.5503  g_loss:1.3256
# epoch:3815  d_Loss:0.6217  g_loss:1.2682
# epoch:3816  d_Loss:0.5297  g_loss:1.2495
# epoch:3817  d_Loss:0.4943  g_loss:1.4549
# epoch:3818  d_Loss:0.4429  g_loss:1.7185
# epoch:3819  d_Loss:0.4525  g_loss:1.5246
# epoch:3820  d_Loss:0.3994  g_loss:1.5903
# epoch:3821  d_Loss:0.4250  g_loss:1.8934
# epoch:3822  d_Loss:0.4880  g_loss:1.6166
# epoch:3823  d_Loss:0.4703  g_loss:1.7006
# epoch:3824  d_Loss:0.4019  g_loss:1.9408
# epoch:3825  d_Loss:0.5096  g_loss:1.5567
# epoch:3826  d_Loss:0.4334  g_loss:1.7388
# epoch:3827  d_Loss:0.3943  g_loss:1.5620
# epoch:3828  d_Loss:0.3710  g_loss:1.9886
# epoch:3829  d_Loss:0.4170  g_loss:1.5335
# epoch:3830  d_Loss:0.5736  g_loss:1.4761
# epoch:3831  d_Loss:0.4465  g_loss:1.8027
# epoch:3832  d_Loss:0.4821  g_loss:1.3755
# epoch:3833  d_Loss:0.5491  g_loss:1.5811
# epoch:3834  d_Loss:0.4466  g_loss:1.4094
# epoch:3835  d_Loss:0.5947  g_loss:1.1623
# epoch:3836  d_Loss:0.5332  g_loss:1.8085
# epoch:3837  d_Loss:0.6155  g_loss:1.2895
# epoch:3838  d_Loss:0.5760  g_loss:1.7619
# epoch:3839  d_Loss:0.7006  g_loss:1.7122
# epoch:3840  d_Loss:0.4480  g_loss:1.2206
# epoch:3841  d_Loss:0.7782  g_loss:1.1936
# epoch:3842  d_Loss:0.7607  g_loss:0.9525
# epoch:3843  d_Loss:0.9119  g_loss:0.8712
# epoch:3844  d_Loss:0.6610  g_loss:1.1296
# epoch:3845  d_Loss:0.6779  g_loss:1.1520
# epoch:3846  d_Loss:0.6157  g_loss:1.4723
# epoch:3847  d_Loss:0.6551  g_loss:1.4582
# epoch:3848  d_Loss:0.6081  g_loss:1.5321
# epoch:3849  d_Loss:0.6784  g_loss:1.3942
# epoch:3850  d_Loss:0.6150  g_loss:1.3382
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# epoch:3851  d_Loss:0.5759  g_loss:1.5041
# epoch:3852  d_Loss:0.5464  g_loss:1.3543
# epoch:3853  d_Loss:0.6444  g_loss:1.3949
# epoch:3854  d_Loss:0.5226  g_loss:1.5824
# epoch:3855  d_Loss:0.4691  g_loss:1.5557
# epoch:3856  d_Loss:0.4889  g_loss:1.7701
# epoch:3857  d_Loss:0.3732  g_loss:1.7718
# epoch:3858  d_Loss:0.4394  g_loss:1.8438
# epoch:3859  d_Loss:0.4904  g_loss:1.3888
# epoch:3860  d_Loss:0.4263  g_loss:1.3914
# epoch:3861  d_Loss:0.3232  g_loss:1.6049
# epoch:3862  d_Loss:0.5597  g_loss:1.5025
# epoch:3863  d_Loss:0.4001  g_loss:1.8495
# epoch:3864  d_Loss:0.5462  g_loss:1.3567
# epoch:3865  d_Loss:0.5346  g_loss:1.9505
# epoch:3866  d_Loss:0.5536  g_loss:1.3309
# epoch:3867  d_Loss:0.5985  g_loss:1.4396
# epoch:3868  d_Loss:0.6410  g_loss:1.2245
# epoch:3869  d_Loss:0.5182  g_loss:1.6619
# epoch:3870  d_Loss:0.6664  g_loss:1.4002
# epoch:3871  d_Loss:0.5615  g_loss:1.5797
# epoch:3872  d_Loss:0.6145  g_loss:1.4608
# epoch:3873  d_Loss:0.5852  g_loss:1.4969
# epoch:3874  d_Loss:0.5634  g_loss:1.3450
# epoch:3875  d_Loss:0.5640  g_loss:1.3687
# epoch:3876  d_Loss:0.5150  g_loss:1.4693
# epoch:3877  d_Loss:0.6225  g_loss:1.3106
# epoch:3878  d_Loss:0.6303  g_loss:1.1743
# epoch:3879  d_Loss:0.6304  g_loss:1.2280
# epoch:3880  d_Loss:0.5472  g_loss:1.6205
# epoch:3881  d_Loss:0.6316  g_loss:1.1798
# epoch:3882  d_Loss:0.7316  g_loss:1.1346
# epoch:3883  d_Loss:0.5382  g_loss:1.2122
# epoch:3884  d_Loss:0.5171  g_loss:1.4517
# epoch:3885  d_Loss:0.6084  g_loss:1.3029
# epoch:3886  d_Loss:0.3494  g_loss:1.5593
# epoch:3887  d_Loss:0.5178  g_loss:1.5909
# epoch:3888  d_Loss:0.4699  g_loss:1.6247
# epoch:3889  d_Loss:0.4308  g_loss:1.8667
# epoch:3890  d_Loss:0.5730  g_loss:1.5397
# epoch:3891  d_Loss:0.5517  g_loss:1.7903
# epoch:3892  d_Loss:0.5086  g_loss:2.0705
# epoch:3893  d_Loss:0.5467  g_loss:1.3746
# epoch:3894  d_Loss:0.4889  g_loss:1.9371
# epoch:3895  d_Loss:0.6082  g_loss:1.8070
# epoch:3896  d_Loss:0.6006  g_loss:1.3180
# epoch:3897  d_Loss:0.4868  g_loss:1.3867
# epoch:3898  d_Loss:0.5496  g_loss:1.3863
# epoch:3899  d_Loss:0.5802  g_loss:1.3100
# epoch:3900  d_Loss:0.4751  g_loss:1.3798
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# epoch:3901  d_Loss:0.4626  g_loss:1.7752
# epoch:3902  d_Loss:0.5094  g_loss:1.5724
# epoch:3903  d_Loss:0.6806  g_loss:1.4101
# epoch:3904  d_Loss:0.5919  g_loss:1.3276
# epoch:3905  d_Loss:0.5842  g_loss:1.2002
# epoch:3906  d_Loss:0.5741  g_loss:1.1357
# epoch:3907  d_Loss:0.5410  g_loss:1.4789
# epoch:3908  d_Loss:0.6374  g_loss:1.4483
# epoch:3909  d_Loss:0.6828  g_loss:1.3954
# epoch:3910  d_Loss:0.5288  g_loss:1.3841
# epoch:3911  d_Loss:0.6724  g_loss:1.2119
# epoch:3912  d_Loss:0.5276  g_loss:0.8997
# epoch:3913  d_Loss:0.6023  g_loss:1.0029
# epoch:3914  d_Loss:0.6800  g_loss:1.3031
# epoch:3915  d_Loss:0.5284  g_loss:1.4157
# epoch:3916  d_Loss:0.6069  g_loss:1.3542
# epoch:3917  d_Loss:0.4311  g_loss:1.5089
# epoch:3918  d_Loss:0.6513  g_loss:1.3759
# epoch:3919  d_Loss:0.5699  g_loss:1.2470
# epoch:3920  d_Loss:0.5329  g_loss:1.4283
# epoch:3921  d_Loss:0.5091  g_loss:1.2217
# epoch:3922  d_Loss:0.4721  g_loss:1.4198
# epoch:3923  d_Loss:0.5578  g_loss:1.2270
# epoch:3924  d_Loss:0.5157  g_loss:1.5070
# epoch:3925  d_Loss:0.4709  g_loss:1.5168
# epoch:3926  d_Loss:0.5577  g_loss:1.8254
# epoch:3927  d_Loss:0.4877  g_loss:1.6858
# epoch:3928  d_Loss:0.5042  g_loss:1.4997
# epoch:3929  d_Loss:0.5058  g_loss:1.1882
# epoch:3930  d_Loss:0.5818  g_loss:1.4167
# epoch:3931  d_Loss:0.5956  g_loss:1.2217
# epoch:3932  d_Loss:0.6662  g_loss:1.1549
# epoch:3933  d_Loss:0.5177  g_loss:1.4296
# epoch:3934  d_Loss:0.4916  g_loss:1.7083
# epoch:3935  d_Loss:0.5029  g_loss:1.7525
# epoch:3936  d_Loss:0.5053  g_loss:1.8443
# epoch:3937  d_Loss:0.6132  g_loss:1.4922
# epoch:3938  d_Loss:0.4834  g_loss:1.3258
# epoch:3939  d_Loss:0.4977  g_loss:1.1640
# epoch:3940  d_Loss:0.5142  g_loss:1.1451
# epoch:3941  d_Loss:0.6810  g_loss:1.0925
# epoch:3942  d_Loss:0.6079  g_loss:1.4056
# epoch:3943  d_Loss:0.5455  g_loss:1.3012
# epoch:3944  d_Loss:0.6929  g_loss:1.3391
# epoch:3945  d_Loss:0.5111  g_loss:1.5059
# epoch:3946  d_Loss:0.5027  g_loss:1.7502
# epoch:3947  d_Loss:0.5818  g_loss:1.5289
# epoch:3948  d_Loss:0.4327  g_loss:1.6494
# epoch:3949  d_Loss:0.5898  g_loss:1.5167
# epoch:3950  d_Loss:0.6017  g_loss:1.1593
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# epoch:3951  d_Loss:0.5579  g_loss:1.2673
# epoch:3952  d_Loss:0.4322  g_loss:1.6759
# epoch:3953  d_Loss:0.6182  g_loss:1.5470
# epoch:3954  d_Loss:0.4562  g_loss:1.7744
# epoch:3955  d_Loss:0.4995  g_loss:1.6473
# epoch:3956  d_Loss:0.5396  g_loss:1.4674
# epoch:3957  d_Loss:0.5918  g_loss:1.6501
# epoch:3958  d_Loss:0.6279  g_loss:1.1965
# epoch:3959  d_Loss:0.7050  g_loss:1.3928
# epoch:3960  d_Loss:0.5338  g_loss:1.1036
# epoch:3961  d_Loss:0.5831  g_loss:1.1954
# epoch:3962  d_Loss:0.5703  g_loss:1.0697
# epoch:3963  d_Loss:0.6408  g_loss:1.5042
# epoch:3964  d_Loss:0.4048  g_loss:1.5004
# epoch:3965  d_Loss:0.4847  g_loss:1.3838
# epoch:3966  d_Loss:0.5516  g_loss:1.6590
# epoch:3967  d_Loss:0.6501  g_loss:1.5040
# epoch:3968  d_Loss:0.6128  g_loss:1.3698
# epoch:3969  d_Loss:0.6821  g_loss:1.2874
# epoch:3970  d_Loss:0.5211  g_loss:1.1165
# epoch:3971  d_Loss:0.5289  g_loss:1.4075
# epoch:3972  d_Loss:0.6084  g_loss:1.1253
# epoch:3973  d_Loss:0.4285  g_loss:1.6183
# epoch:3974  d_Loss:0.4509  g_loss:1.5299
# epoch:3975  d_Loss:0.5072  g_loss:1.8308
# epoch:3976  d_Loss:0.4884  g_loss:1.5335
# epoch:3977  d_Loss:0.6083  g_loss:1.4194
# epoch:3978  d_Loss:0.4849  g_loss:1.1814
# epoch:3979  d_Loss:0.5786  g_loss:1.2592
# epoch:3980  d_Loss:0.5239  g_loss:1.3692
# epoch:3981  d_Loss:0.4414  g_loss:1.7630
# epoch:3982  d_Loss:0.4065  g_loss:1.6368
# epoch:3983  d_Loss:0.5415  g_loss:1.4247
# epoch:3984  d_Loss:0.5453  g_loss:1.2100
# epoch:3985  d_Loss:0.4671  g_loss:1.8278
# epoch:3986  d_Loss:0.4829  g_loss:1.8662
# epoch:3987  d_Loss:0.4875  g_loss:1.8095
# epoch:3988  d_Loss:0.4883  g_loss:1.7917
# epoch:3989  d_Loss:0.5362  g_loss:1.4673
# epoch:3990  d_Loss:0.5468  g_loss:1.2523
# epoch:3991  d_Loss:0.4612  g_loss:1.5983
# epoch:3992  d_Loss:0.5061  g_loss:1.5094
# epoch:3993  d_Loss:0.6526  g_loss:1.4803
# epoch:3994  d_Loss:0.5417  g_loss:1.6210
# epoch:3995  d_Loss:0.6872  g_loss:1.5594
# epoch:3996  d_Loss:0.7743  g_loss:1.2730
# epoch:3997  d_Loss:0.6220  g_loss:1.2929
# epoch:3998  d_Loss:0.5638  g_loss:1.3725
# epoch:3999  d_Loss:0.7046  g_loss:1.0183
# epoch:4000  d_Loss:0.6002  g_loss:1.2306
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
model_dir = './Gan_model'
if not os.path.exists(model_dir):
    os.mkdir(model_dir)
g_model.save_weights('my_g_model.h5')

# %%
from pandas import Series, DataFrame
import pandas as pd 

df = DataFrame(history, columns=['epoch', 'd_loss', 'g_loss'])

df.plot(y=['d_loss', 'g_loss'])
plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
# def gan_train(epoch, batch_size, saving_interval) :
#     (X_train, _), (_,_) = mnist.load_data()
#     X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
#     X_train = (X_train -127.5) / 127.5
#     true = np.ones((batch_size, 1))
#     fake = np.zeros((batch_size, 1))
    
#     for i in range(epoch) :
#         idx = np.random.randint(0, X_train.shape[0], batch_size)
#         imgs = X_train[idx]
#         d_loss_real = d_model.train_on_batch(imgs, true)
        
#         noise = np.random.normal(0, 1, (batch_size, 100))
#         gen_imgs = g_model.predict(noise)
#         d_loss_fake = d_model.train_on_batch(gen_imgs, fake) 
        
#         d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
#         g_loss = gan.train_on_batch(noise, true) 
        
#         print('epoch:%d' %i, ' dLoss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss) 
        
#         if i % saving_interval == 0:
#             #r, c = 5, 5
#             noise = np.random.normal(0, 1, (25, 100))
#             gen_imgs = g_model.predict(noise)

#             # Rescale images 0 - 1
#             gen_imgs = 0.5 * gen_imgs + 0.5

#             fig, axs = plt.subplots(5, 5)
#             count = 0
#             for j in range(5):
#               for k in range(5):
#                   axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
#                   axs[j, k].axis('off')
#                   count += 1
#             fig.savefig("gan_images/gan_mnist_%d.png" % i)
